# %%
from sklearn.datasets import *
from sklearn.neighbors import KNeighborsRegressor
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
boston = load_boston()
print(boston["filename"])
boston.keys()
# Out:
# D:\PROGRAMS\python\anaconda3\lib\site-packages\sklearn\datasets\data\boston_house_prices.csv
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
bos = pd.DataFrame(boston['data'])
bos.columns = boston['feature_names']
bos['Price'] = boston['target']
bos.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
def calcolateMSE(y_true, y_pred):
    return mean_squared_error(y_true, y_pred)

def predictWithKnnInput(knn, train_x, train_y, to_be_predicted):
    return knn.predict(to_be_predicted)

def instantiateKnn(metricgiven, n_neighbors, weights="uniform", algorithm="auto"):
    knn = KNeighborsRegressor(n_neighbors, metric=metricgiven, weights=weights, algorithm=algorithm)
    return knn

def predictWithBestParameters(train_x, train_y, metrics_list, weights_list, value_to_predict, real_value):
    best = {"prediction": None, "mse": None, "n_neighbors": None, "metric": None, "weights": None}
    for weights in weights_list:
        for n_neighbors in range(1, train_x.shape[0]+1):
            for metric in metrics_list:
                #                 print(f"{metric} {n_neighbors} {weights}")
                knn_i = instantiateKnn(metric, n_neighbors, weights)
                #                 train_x_1 = train_x.copy()
                #                 train_y_1 = train_y.copy()
                #                 print(train_x.shape, train_y.shape)
                knn_i.fit(train_x, train_y)
                prediction = knn_i.predict(value_to_predict)
                mse = calcolateMSE([real_value],[prediction])
                if (best["mse"] == None or mse < best["mse"]):
                    best = {"prediction": prediction, "mse": mse, "n_neighbors": n_neighbors, "metric": metric, "weights": weights}
    return best

# %%
# metrics which need parameters cannot be run with auto -> ball_tree seems problematic
metrics_list = ["chebyshev", "minkowski", "manhattan", "euclidean"]
weights_list = ["uniform", "distance"]

# %%
train_x = boston['data'][:500]
train_y = boston['target'][:500]


            
KNR = KNeighborsRegressor(499, metric="manhattan", weights="uniform", leaf_size=30)

print(KNR)

KNR.fit(train_x, train_y)

# print(train_x)


test = np.array(boston['data'][504])
test1 = test.reshape(1,-1)

print(test1)

# bos.loc[500:]
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='manhattan',
#                     metric_params=None, n_jobs=None, n_neighbors=499, p=2,
#                     weights='uniform')
# [[1.0959e-01 0.0000e+00 1.1930e+01 0.0000e+00 5.7300e-01 6.7940e+00
#   8.9300e+01 2.3889e+00 1.0000e+00 2.7300e+02 2.1000e+01 3.9345e+02
#   6.4800e+00]]

# %%
KNR.predict(test1)
# Out:
# array([22.59559118])

# %%
calcolateMSE([22],[KNeighborsRegressor(499, metric="manhattan", weights="uniform", leaf_size=30).fit(train_x, train_y)
.predict(test1)])
# Out:
# 0.3547288565106194

# %%
calcolateMSE([22],[KNeighborsRegressor(499, metric="mahalanobis", weights="uniform", leaf_size=50).fit(train_x, train_y)
.predict(test1)])
# Out:
# 0.3509197151818695

# %%
best_parameters = predictWithBestParameters(train_x, train_y, metrics_list, weights_list, test1, 22)
# Out:
# chebyshev 1 uniform
# (500, 13) (500,)
# minkowski 1 uniform
# (500, 13) (500,)
# manhattan 1 uniform
# (500, 13) (500,)
# euclidean 1 uniform
# (500, 13) (500,)
# chebyshev 2 uniform
# (500, 13) (500,)
# minkowski 2 uniform
# (500, 13) (500,)
# manhattan 2 uniform
# (500, 13) (500,)
# euclidean 2 uniform
# (500, 13) (500,)
# chebyshev 3 uniform
# (500, 13) (500,)
# minkowski 3 uniform
# (500, 13) (500,)
# manhattan 3 uniform
# (500, 13) (500,)
# euclidean 3 uniform
# (500, 13) (500,)
# chebyshev 4 uniform
# (500, 13) (500,)
# minkowski 4 uniform
# (500, 13) (500,)
# manhattan 4 uniform
# (500, 13) (500,)
# euclidean 4 uniform
# (500, 13) (500,)
# chebyshev 5 uniform
# (500, 13) (500,)
# minkowski 5 uniform
# (500, 13) (500,)
# manhattan 5 uniform
# (500, 13) (500,)
# euclidean 5 uniform
# (500, 13) (500,)
# chebyshev 6 uniform
# (500, 13) (500,)
# minkowski 6 uniform
# (500, 13) (500,)
# manhattan 6 uniform
# (500, 13) (500,)
# euclidean 6 uniform
# (500, 13) (500,)
# chebyshev 7 uniform
# (500, 13) (500,)
# minkowski 7 uniform
# (500, 13) (500,)
# manhattan 7 uniform
# (500, 13) (500,)
# euclidean 7 uniform
# (500, 13) (500,)
# chebyshev 8 uniform
# (500, 13) (500,)
# minkowski 8 uniform
# (500, 13) (500,)
# manhattan 8 uniform
# (500, 13) (500,)
# euclidean 8 uniform
# (500, 13) (500,)
# chebyshev 9 uniform
# (500, 13) (500,)
# minkowski 9 uniform
# (500, 13) (500,)
# manhattan 9 uniform
# (500, 13) (500,)
# euclidean 9 uniform
# (500, 13) (500,)
# chebyshev 10 uniform
# (500, 13) (500,)
# minkowski 10 uniform
# (500, 13) (500,)
# manhattan 10 uniform
# (500, 13) (500,)
# euclidean 10 uniform
# (500, 13) (500,)
# chebyshev 11 uniform
# (500, 13) (500,)
# minkowski 11 uniform
# (500, 13) (500,)
# manhattan 11 uniform
# (500, 13) (500,)
# euclidean 11 uniform
# (500, 13) (500,)
# chebyshev 12 uniform
# (500, 13) (500,)
# minkowski 12 uniform
# (500, 13) (500,)
# manhattan 12 uniform
# (500, 13) (500,)
# euclidean 12 uniform
# (500, 13) (500,)
# chebyshev 13 uniform
# (500, 13) (500,)
# minkowski 13 uniform
# (500, 13) (500,)
# manhattan 13 uniform
# (500, 13) (500,)
# euclidean 13 uniform
# (500, 13) (500,)
# chebyshev 14 uniform
# (500, 13) (500,)
# minkowski 14 uniform
# (500, 13) (500,)
# manhattan 14 uniform
# (500, 13) (500,)
# euclidean 14 uniform
# (500, 13) (500,)
# chebyshev 15 uniform
# (500, 13) (500,)
# minkowski 15 uniform
# (500, 13) (500,)
# manhattan 15 uniform
# (500, 13) (500,)
# euclidean 15 uniform
# (500, 13) (500,)
# chebyshev 16 uniform
# (500, 13) (500,)
# minkowski 16 uniform
# (500, 13) (500,)
# manhattan 16 uniform
# (500, 13) (500,)
# euclidean 16 uniform
# (500, 13) (500,)
# chebyshev 17 uniform
# (500, 13) (500,)
# minkowski 17 uniform
# (500, 13) (500,)
# manhattan 17 uniform
# (500, 13) (500,)
# euclidean 17 uniform
# (500, 13) (500,)
# chebyshev 18 uniform
# (500, 13) (500,)
# minkowski 18 uniform
# (500, 13) (500,)
# manhattan 18 uniform
# (500, 13) (500,)
# euclidean 18 uniform
# (500, 13) (500,)
# chebyshev 19 uniform
# (500, 13) (500,)
# minkowski 19 uniform
# (500, 13) (500,)
# manhattan 19 uniform
# (500, 13) (500,)
# euclidean 19 uniform
# (500, 13) (500,)
# chebyshev 20 uniform
# (500, 13) (500,)
# minkowski 20 uniform
# (500, 13) (500,)
# manhattan 20 uniform
# (500, 13) (500,)
# euclidean 20 uniform
# (500, 13) (500,)
# chebyshev 21 uniform
# (500, 13) (500,)
# minkowski 21 uniform
# (500, 13) (500,)
# manhattan 21 uniform
# (500, 13) (500,)
# euclidean 21 uniform
# (500, 13) (500,)
# chebyshev 22 uniform
# (500, 13) (500,)
# minkowski 22 uniform
# (500, 13) (500,)
# manhattan 22 uniform
# (500, 13) (500,)
# euclidean 22 uniform
# (500, 13) (500,)
# chebyshev 23 uniform
# (500, 13) (500,)
# minkowski 23 uniform
# (500, 13) (500,)
# manhattan 23 uniform
# (500, 13) (500,)
# euclidean 23 uniform
# (500, 13) (500,)
# chebyshev 24 uniform
# (500, 13) (500,)
# minkowski 24 uniform
# (500, 13) (500,)
# manhattan 24 uniform
# (500, 13) (500,)
# euclidean 24 uniform
# (500, 13) (500,)
# chebyshev 25 uniform
# (500, 13) (500,)
# minkowski 25 uniform
# (500, 13) (500,)
# manhattan 25 uniform
# (500, 13) (500,)
# euclidean 25 uniform
# (500, 13) (500,)
# chebyshev 26 uniform
# (500, 13) (500,)
# minkowski 26 uniform
# (500, 13) (500,)
# manhattan 26 uniform
# (500, 13) (500,)
# euclidean 26 uniform
# (500, 13) (500,)
# chebyshev 27 uniform
# (500, 13) (500,)
# minkowski 27 uniform
# (500, 13) (500,)
# manhattan 27 uniform
# (500, 13) (500,)
# euclidean 27 uniform
# (500, 13) (500,)
# chebyshev 28 uniform
# (500, 13) (500,)
# minkowski 28 uniform
# (500, 13) (500,)
# manhattan 28 uniform
# (500, 13) (500,)
# euclidean 28 uniform
# (500, 13) (500,)
# chebyshev 29 uniform
# (500, 13) (500,)
# minkowski 29 uniform
# (500, 13) (500,)
# manhattan 29 uniform
# (500, 13) (500,)
# euclidean 29 uniform
# (500, 13) (500,)
# chebyshev 30 uniform
# (500, 13) (500,)
# minkowski 30 uniform
# (500, 13) (500,)
# manhattan 30 uniform
# (500, 13) (500,)
# euclidean 30 uniform
# (500, 13) (500,)
# chebyshev 31 uniform
# (500, 13) (500,)
# minkowski 31 uniform
# (500, 13) (500,)
# manhattan 31 uniform
# (500, 13) (500,)
# euclidean 31 uniform
# (500, 13) (500,)
# chebyshev 32 uniform
# (500, 13) (500,)
# minkowski 32 uniform
# (500, 13) (500,)
# manhattan 32 uniform
# (500, 13) (500,)
# euclidean 32 uniform
# (500, 13) (500,)
# chebyshev 33 uniform
# (500, 13) (500,)
# minkowski 33 uniform
# (500, 13) (500,)
# manhattan 33 uniform
# (500, 13) (500,)
# euclidean 33 uniform
# (500, 13) (500,)
# chebyshev 34 uniform
# (500, 13) (500,)
# minkowski 34 uniform
# (500, 13) (500,)
# manhattan 34 uniform
# (500, 13) (500,)
# euclidean 34 uniform
# (500, 13) (500,)
# chebyshev 35 uniform
# (500, 13) (500,)
# minkowski 35 uniform
# (500, 13) (500,)
# manhattan 35 uniform
# (500, 13) (500,)
# euclidean 35 uniform
# (500, 13) (500,)
# chebyshev 36 uniform
# (500, 13) (500,)
# minkowski 36 uniform
# (500, 13) (500,)
# manhattan 36 uniform
# (500, 13) (500,)
# euclidean 36 uniform
# (500, 13) (500,)
# chebyshev 37 uniform
# (500, 13) (500,)
# minkowski 37 uniform
# (500, 13) (500,)
# manhattan 37 uniform
# (500, 13) (500,)
# euclidean 37 uniform
# (500, 13) (500,)
# chebyshev 38 uniform
# (500, 13) (500,)
# minkowski 38 uniform
# (500, 13) (500,)
# manhattan 38 uniform
# (500, 13) (500,)
# euclidean 38 uniform
# (500, 13) (500,)
# chebyshev 39 uniform
# (500, 13) (500,)
# minkowski 39 uniform
# (500, 13) (500,)
# manhattan 39 uniform
# (500, 13) (500,)
# euclidean 39 uniform
# (500, 13) (500,)
# chebyshev 40 uniform
# (500, 13) (500,)
# minkowski 40 uniform
# (500, 13) (500,)
# manhattan 40 uniform
# (500, 13) (500,)
# euclidean 40 uniform
# (500, 13) (500,)
# chebyshev 41 uniform
# (500, 13) (500,)
# minkowski 41 uniform
# (500, 13) (500,)
# manhattan 41 uniform
# (500, 13) (500,)
# euclidean 41 uniform
# (500, 13) (500,)
# chebyshev 42 uniform
# (500, 13) (500,)
# minkowski 42 uniform
# (500, 13) (500,)
# manhattan 42 uniform
# (500, 13) (500,)
# euclidean 42 uniform
# (500, 13) (500,)
# chebyshev 43 uniform
# (500, 13) (500,)
# minkowski 43 uniform
# (500, 13) (500,)
# manhattan 43 uniform
# (500, 13) (500,)
# euclidean 43 uniform
# (500, 13) (500,)
# chebyshev 44 uniform
# (500, 13) (500,)
# minkowski 44 uniform
# (500, 13) (500,)
# manhattan 44 uniform
# (500, 13) (500,)
# euclidean 44 uniform
# (500, 13) (500,)
# chebyshev 45 uniform
# (500, 13) (500,)
# minkowski 45 uniform
# (500, 13) (500,)
# manhattan 45 uniform
# (500, 13) (500,)
# euclidean 45 uniform
# (500, 13) (500,)
# chebyshev 46 uniform
# (500, 13) (500,)
# minkowski 46 uniform
# (500, 13) (500,)
# manhattan 46 uniform
# (500, 13) (500,)
# euclidean 46 uniform
# (500, 13) (500,)
# chebyshev 47 uniform
# (500, 13) (500,)
# minkowski 47 uniform
# (500, 13) (500,)
# manhattan 47 uniform
# (500, 13) (500,)
# euclidean 47 uniform
# (500, 13) (500,)
# chebyshev 48 uniform
# (500, 13) (500,)
# minkowski 48 uniform
# (500, 13) (500,)
# manhattan 48 uniform
# (500, 13) (500,)
# euclidean 48 uniform
# (500, 13) (500,)
# chebyshev 49 uniform
# (500, 13) (500,)
# minkowski 49 uniform
# (500, 13) (500,)
# manhattan 49 uniform
# (500, 13) (500,)
# euclidean 49 uniform
# (500, 13) (500,)
# chebyshev 50 uniform
# (500, 13) (500,)
# minkowski 50 uniform
# (500, 13) (500,)
# manhattan 50 uniform
# (500, 13) (500,)
# euclidean 50 uniform
# (500, 13) (500,)
# chebyshev 51 uniform
# (500, 13) (500,)
# minkowski 51 uniform
# (500, 13) (500,)
# manhattan 51 uniform
# (500, 13) (500,)
# euclidean 51 uniform
# (500, 13) (500,)
# chebyshev 52 uniform
# (500, 13) (500,)
# minkowski 52 uniform
# (500, 13) (500,)
# manhattan 52 uniform
# (500, 13) (500,)
# euclidean 52 uniform
# (500, 13) (500,)
# chebyshev 53 uniform
# (500, 13) (500,)
# minkowski 53 uniform
# (500, 13) (500,)
# manhattan 53 uniform
# (500, 13) (500,)
# euclidean 53 uniform
# (500, 13) (500,)
# chebyshev 54 uniform
# (500, 13) (500,)
# minkowski 54 uniform
# (500, 13) (500,)
# manhattan 54 uniform
# (500, 13) (500,)
# euclidean 54 uniform
# (500, 13) (500,)
# chebyshev 55 uniform
# (500, 13) (500,)
# minkowski 55 uniform
# (500, 13) (500,)
# manhattan 55 uniform
# (500, 13) (500,)
# euclidean 55 uniform
# (500, 13) (500,)
# chebyshev 56 uniform
# (500, 13) (500,)
# minkowski 56 uniform
# (500, 13) (500,)
# manhattan 56 uniform
# (500, 13) (500,)
# euclidean 56 uniform
# (500, 13) (500,)
# chebyshev 57 uniform
# (500, 13) (500,)
# minkowski 57 uniform
# (500, 13) (500,)
# manhattan 57 uniform
# (500, 13) (500,)
# euclidean 57 uniform
# (500, 13) (500,)
# chebyshev 58 uniform
# (500, 13) (500,)
# minkowski 58 uniform
# (500, 13) (500,)
# manhattan 58 uniform
# (500, 13) (500,)
# euclidean 58 uniform
# (500, 13) (500,)
# chebyshev 59 uniform
# (500, 13) (500,)
# minkowski 59 uniform
# (500, 13) (500,)
# manhattan 59 uniform
# (500, 13) (500,)
# euclidean 59 uniform
# (500, 13) (500,)
# chebyshev 60 uniform
# (500, 13) (500,)
# minkowski 60 uniform
# (500, 13) (500,)
# manhattan 60 uniform
# (500, 13) (500,)
# euclidean 60 uniform
# (500, 13) (500,)
# chebyshev 61 uniform
# (500, 13) (500,)
# minkowski 61 uniform
# (500, 13) (500,)
# manhattan 61 uniform
# (500, 13) (500,)
# euclidean 61 uniform
# (500, 13) (500,)
# chebyshev 62 uniform
# (500, 13) (500,)
# minkowski 62 uniform
# (500, 13) (500,)
# manhattan 62 uniform
# (500, 13) (500,)
# euclidean 62 uniform
# (500, 13) (500,)
# chebyshev 63 uniform
# (500, 13) (500,)
# minkowski 63 uniform
# (500, 13) (500,)
# manhattan 63 uniform
# (500, 13) (500,)
# euclidean 63 uniform
# (500, 13) (500,)
# chebyshev 64 uniform
# (500, 13) (500,)
# minkowski 64 uniform
# (500, 13) (500,)
# manhattan 64 uniform
# (500, 13) (500,)
# euclidean 64 uniform
# (500, 13) (500,)
# chebyshev 65 uniform
# (500, 13) (500,)
# minkowski 65 uniform
# (500, 13) (500,)
# manhattan 65 uniform
# (500, 13) (500,)
# euclidean 65 uniform
# (500, 13) (500,)
# chebyshev 66 uniform
# (500, 13) (500,)
# minkowski 66 uniform
# (500, 13) (500,)
# manhattan 66 uniform
# (500, 13) (500,)
# euclidean 66 uniform
# (500, 13) (500,)
# chebyshev 67 uniform
# (500, 13) (500,)
# minkowski 67 uniform
# (500, 13) (500,)
# manhattan 67 uniform
# (500, 13) (500,)
# euclidean 67 uniform
# (500, 13) (500,)
# chebyshev 68 uniform
# (500, 13) (500,)
# minkowski 68 uniform
# (500, 13) (500,)
# manhattan 68 uniform
# (500, 13) (500,)
# euclidean 68 uniform
# (500, 13) (500,)
# chebyshev 69 uniform
# (500, 13) (500,)
# minkowski 69 uniform
# (500, 13) (500,)
# manhattan 69 uniform
# (500, 13) (500,)
# euclidean 69 uniform
# (500, 13) (500,)
# chebyshev 70 uniform
# (500, 13) (500,)
# minkowski 70 uniform
# (500, 13) (500,)
# manhattan 70 uniform
# (500, 13) (500,)
# euclidean 70 uniform
# (500, 13) (500,)
# chebyshev 71 uniform
# (500, 13) (500,)
# minkowski 71 uniform
# (500, 13) (500,)
# manhattan 71 uniform
# (500, 13) (500,)
# euclidean 71 uniform
# (500, 13) (500,)
# chebyshev 72 uniform
# (500, 13) (500,)
# minkowski 72 uniform
# (500, 13) (500,)
# manhattan 72 uniform
# (500, 13) (500,)
# euclidean 72 uniform
# (500, 13) (500,)
# chebyshev 73 uniform
# (500, 13) (500,)
# minkowski 73 uniform
# (500, 13) (500,)
# manhattan 73 uniform
# (500, 13) (500,)
# euclidean 73 uniform
# (500, 13) (500,)
# chebyshev 74 uniform
# (500, 13) (500,)
# minkowski 74 uniform
# (500, 13) (500,)
# manhattan 74 uniform
# (500, 13) (500,)
# euclidean 74 uniform
# (500, 13) (500,)
# chebyshev 75 uniform
# (500, 13) (500,)
# minkowski 75 uniform
# (500, 13) (500,)
# manhattan 75 uniform
# (500, 13) (500,)
# euclidean 75 uniform
# (500, 13) (500,)
# chebyshev 76 uniform
# (500, 13) (500,)
# minkowski 76 uniform
# (500, 13) (500,)
# manhattan 76 uniform
# (500, 13) (500,)
# euclidean 76 uniform
# (500, 13) (500,)
# chebyshev 77 uniform
# (500, 13) (500,)
# minkowski 77 uniform
# (500, 13) (500,)
# manhattan 77 uniform
# (500, 13) (500,)
# euclidean 77 uniform
# (500, 13) (500,)
# chebyshev 78 uniform
# (500, 13) (500,)
# minkowski 78 uniform
# (500, 13) (500,)
# manhattan 78 uniform
# (500, 13) (500,)
# euclidean 78 uniform
# (500, 13) (500,)
# chebyshev 79 uniform
# (500, 13) (500,)
# minkowski 79 uniform
# (500, 13) (500,)
# manhattan 79 uniform
# (500, 13) (500,)
# euclidean 79 uniform
# (500, 13) (500,)
# chebyshev 80 uniform
# (500, 13) (500,)
# minkowski 80 uniform
# (500, 13) (500,)
# manhattan 80 uniform
# (500, 13) (500,)
# euclidean 80 uniform
# (500, 13) (500,)
# chebyshev 81 uniform
# (500, 13) (500,)
# minkowski 81 uniform
# (500, 13) (500,)
# manhattan 81 uniform
# (500, 13) (500,)
# euclidean 81 uniform
# (500, 13) (500,)
# chebyshev 82 uniform
# (500, 13) (500,)
# minkowski 82 uniform
# (500, 13) (500,)
# manhattan 82 uniform
# (500, 13) (500,)
# euclidean 82 uniform
# (500, 13) (500,)
# chebyshev 83 uniform
# (500, 13) (500,)
# minkowski 83 uniform
# (500, 13) (500,)
# manhattan 83 uniform
# (500, 13) (500,)
# euclidean 83 uniform
# (500, 13) (500,)
# chebyshev 84 uniform
# (500, 13) (500,)
# minkowski 84 uniform
# (500, 13) (500,)
# manhattan 84 uniform
# (500, 13) (500,)
# euclidean 84 uniform
# (500, 13) (500,)
# chebyshev 85 uniform
# (500, 13) (500,)
# minkowski 85 uniform
# (500, 13) (500,)
# manhattan 85 uniform
# (500, 13) (500,)
# euclidean 85 uniform
# (500, 13) (500,)
# chebyshev 86 uniform
# (500, 13) (500,)
# minkowski 86 uniform
# (500, 13) (500,)
# manhattan 86 uniform
# (500, 13) (500,)
# euclidean 86 uniform
# (500, 13) (500,)
# chebyshev 87 uniform
# (500, 13) (500,)
# minkowski 87 uniform
# (500, 13) (500,)
# manhattan 87 uniform
# (500, 13) (500,)
# euclidean 87 uniform
# (500, 13) (500,)
# chebyshev 88 uniform
# (500, 13) (500,)
# minkowski 88 uniform
# (500, 13) (500,)
# manhattan 88 uniform
# (500, 13) (500,)
# euclidean 88 uniform
# (500, 13) (500,)
# chebyshev 89 uniform
# (500, 13) (500,)
# minkowski 89 uniform
# (500, 13) (500,)
# manhattan 89 uniform
# (500, 13) (500,)
# euclidean 89 uniform
# (500, 13) (500,)
# chebyshev 90 uniform
# (500, 13) (500,)
# minkowski 90 uniform
# (500, 13) (500,)
# manhattan 90 uniform
# (500, 13) (500,)
# euclidean 90 uniform
# (500, 13) (500,)
# chebyshev 91 uniform
# (500, 13) (500,)
# minkowski 91 uniform
# (500, 13) (500,)
# manhattan 91 uniform
# (500, 13) (500,)
# euclidean 91 uniform
# (500, 13) (500,)
# chebyshev 92 uniform
# (500, 13) (500,)
# minkowski 92 uniform
# (500, 13) (500,)
# manhattan 92 uniform
# (500, 13) (500,)
# euclidean 92 uniform
# (500, 13) (500,)
# chebyshev 93 uniform
# (500, 13) (500,)
# minkowski 93 uniform
# (500, 13) (500,)
# manhattan 93 uniform
# (500, 13) (500,)
# euclidean 93 uniform
# (500, 13) (500,)
# chebyshev 94 uniform
# (500, 13) (500,)
# minkowski 94 uniform
# (500, 13) (500,)
# manhattan 94 uniform
# (500, 13) (500,)
# euclidean 94 uniform
# (500, 13) (500,)
# chebyshev 95 uniform
# (500, 13) (500,)
# minkowski 95 uniform
# (500, 13) (500,)
# manhattan 95 uniform
# (500, 13) (500,)
# euclidean 95 uniform
# (500, 13) (500,)
# chebyshev 96 uniform
# (500, 13) (500,)
# minkowski 96 uniform
# (500, 13) (500,)
# manhattan 96 uniform
# (500, 13) (500,)
# euclidean 96 uniform
# (500, 13) (500,)
# chebyshev 97 uniform
# (500, 13) (500,)
# minkowski 97 uniform
# (500, 13) (500,)
# manhattan 97 uniform
# (500, 13) (500,)
# euclidean 97 uniform
# (500, 13) (500,)
# chebyshev 98 uniform
# (500, 13) (500,)
# minkowski 98 uniform
# (500, 13) (500,)
# manhattan 98 uniform
# (500, 13) (500,)
# euclidean 98 uniform
# (500, 13) (500,)
# chebyshev 99 uniform
# (500, 13) (500,)
# minkowski 99 uniform
# (500, 13) (500,)
# manhattan 99 uniform
# (500, 13) (500,)
# euclidean 99 uniform
# (500, 13) (500,)
# chebyshev 100 uniform
# (500, 13) (500,)
# minkowski 100 uniform
# (500, 13) (500,)
# manhattan 100 uniform
# (500, 13) (500,)
# euclidean 100 uniform
# (500, 13) (500,)
# chebyshev 101 uniform
# (500, 13) (500,)
# minkowski 101 uniform
# (500, 13) (500,)
# manhattan 101 uniform
# (500, 13) (500,)
# euclidean 101 uniform
# (500, 13) (500,)
# chebyshev 102 uniform
# (500, 13) (500,)
# minkowski 102 uniform
# (500, 13) (500,)
# manhattan 102 uniform
# (500, 13) (500,)
# euclidean 102 uniform
# (500, 13) (500,)
# chebyshev 103 uniform
# (500, 13) (500,)
# minkowski 103 uniform
# (500, 13) (500,)
# manhattan 103 uniform
# (500, 13) (500,)
# euclidean 103 uniform
# (500, 13) (500,)
# chebyshev 104 uniform
# (500, 13) (500,)
# minkowski 104 uniform
# (500, 13) (500,)
# manhattan 104 uniform
# (500, 13) (500,)
# euclidean 104 uniform
# (500, 13) (500,)
# chebyshev 105 uniform
# (500, 13) (500,)
# minkowski 105 uniform
# (500, 13) (500,)
# manhattan 105 uniform
# (500, 13) (500,)
# euclidean 105 uniform
# (500, 13) (500,)
# chebyshev 106 uniform
# (500, 13) (500,)
# minkowski 106 uniform
# (500, 13) (500,)
# manhattan 106 uniform
# (500, 13) (500,)
# euclidean 106 uniform
# (500, 13) (500,)
# chebyshev 107 uniform
# (500, 13) (500,)
# minkowski 107 uniform
# (500, 13) (500,)
# manhattan 107 uniform
# (500, 13) (500,)
# euclidean 107 uniform
# (500, 13) (500,)
# chebyshev 108 uniform
# (500, 13) (500,)
# minkowski 108 uniform
# (500, 13) (500,)
# manhattan 108 uniform
# (500, 13) (500,)
# euclidean 108 uniform
# (500, 13) (500,)
# chebyshev 109 uniform
# (500, 13) (500,)
# minkowski 109 uniform
# (500, 13) (500,)
# manhattan 109 uniform
# (500, 13) (500,)
# euclidean 109 uniform
# (500, 13) (500,)
# chebyshev 110 uniform
# (500, 13) (500,)
# minkowski 110 uniform
# (500, 13) (500,)
# manhattan 110 uniform
# (500, 13) (500,)
# euclidean 110 uniform
# (500, 13) (500,)
# chebyshev 111 uniform
# (500, 13) (500,)
# minkowski 111 uniform
# (500, 13) (500,)
# manhattan 111 uniform
# (500, 13) (500,)
# euclidean 111 uniform
# (500, 13) (500,)
# chebyshev 112 uniform
# (500, 13) (500,)
# minkowski 112 uniform
# (500, 13) (500,)
# manhattan 112 uniform
# (500, 13) (500,)
# euclidean 112 uniform
# (500, 13) (500,)
# chebyshev 113 uniform
# (500, 13) (500,)
# minkowski 113 uniform
# (500, 13) (500,)
# manhattan 113 uniform
# (500, 13) (500,)
# euclidean 113 uniform
# (500, 13) (500,)
# chebyshev 114 uniform
# (500, 13) (500,)
# minkowski 114 uniform
# (500, 13) (500,)
# manhattan 114 uniform
# (500, 13) (500,)
# euclidean 114 uniform
# (500, 13) (500,)
# chebyshev 115 uniform
# (500, 13) (500,)
# minkowski 115 uniform
# (500, 13) (500,)
# manhattan 115 uniform
# (500, 13) (500,)
# euclidean 115 uniform
# (500, 13) (500,)
# chebyshev 116 uniform
# (500, 13) (500,)
# minkowski 116 uniform
# (500, 13) (500,)
# manhattan 116 uniform
# (500, 13) (500,)
# euclidean 116 uniform
# (500, 13) (500,)
# chebyshev 117 uniform
# (500, 13) (500,)
# minkowski 117 uniform
# (500, 13) (500,)
# manhattan 117 uniform
# (500, 13) (500,)
# euclidean 117 uniform
# (500, 13) (500,)
# chebyshev 118 uniform
# (500, 13) (500,)
# minkowski 118 uniform
# (500, 13) (500,)
# manhattan 118 uniform
# (500, 13) (500,)
# euclidean 118 uniform
# (500, 13) (500,)
# chebyshev 119 uniform
# (500, 13) (500,)
# minkowski 119 uniform
# (500, 13) (500,)
# manhattan 119 uniform
# (500, 13) (500,)
# euclidean 119 uniform
# (500, 13) (500,)
# chebyshev 120 uniform
# (500, 13) (500,)
# minkowski 120 uniform
# (500, 13) (500,)
# manhattan 120 uniform
# (500, 13) (500,)
# euclidean 120 uniform
# (500, 13) (500,)
# chebyshev 121 uniform
# (500, 13) (500,)
# minkowski 121 uniform
# (500, 13) (500,)
# manhattan 121 uniform
# (500, 13) (500,)
# euclidean 121 uniform
# (500, 13) (500,)
# chebyshev 122 uniform
# (500, 13) (500,)
# minkowski 122 uniform
# (500, 13) (500,)
# manhattan 122 uniform
# (500, 13) (500,)
# euclidean 122 uniform
# (500, 13) (500,)
# chebyshev 123 uniform
# (500, 13) (500,)
# minkowski 123 uniform
# (500, 13) (500,)
# manhattan 123 uniform
# (500, 13) (500,)
# euclidean 123 uniform
# (500, 13) (500,)
# chebyshev 124 uniform
# (500, 13) (500,)
# minkowski 124 uniform
# (500, 13) (500,)
# manhattan 124 uniform
# (500, 13) (500,)
# euclidean 124 uniform
# (500, 13) (500,)
# chebyshev 125 uniform
# (500, 13) (500,)
# minkowski 125 uniform
# (500, 13) (500,)
# manhattan 125 uniform
# (500, 13) (500,)
# euclidean 125 uniform
# (500, 13) (500,)
# chebyshev 126 uniform
# (500, 13) (500,)
# minkowski 126 uniform
# (500, 13) (500,)
# manhattan 126 uniform
# (500, 13) (500,)
# euclidean 126 uniform
# (500, 13) (500,)
# chebyshev 127 uniform
# (500, 13) (500,)
# minkowski 127 uniform
# (500, 13) (500,)
# manhattan 127 uniform
# (500, 13) (500,)
# euclidean 127 uniform
# (500, 13) (500,)
# chebyshev 128 uniform
# (500, 13) (500,)
# minkowski 128 uniform
# (500, 13) (500,)
# manhattan 128 uniform
# (500, 13) (500,)
# euclidean 128 uniform
# (500, 13) (500,)
# chebyshev 129 uniform
# (500, 13) (500,)
# minkowski 129 uniform
# (500, 13) (500,)
# manhattan 129 uniform
# (500, 13) (500,)
# euclidean 129 uniform
# (500, 13) (500,)
# chebyshev 130 uniform
# (500, 13) (500,)
# minkowski 130 uniform
# (500, 13) (500,)
# manhattan 130 uniform
# (500, 13) (500,)
# euclidean 130 uniform
# (500, 13) (500,)
# chebyshev 131 uniform
# (500, 13) (500,)
# minkowski 131 uniform
# (500, 13) (500,)
# manhattan 131 uniform
# (500, 13) (500,)
# euclidean 131 uniform
# (500, 13) (500,)
# chebyshev 132 uniform
# (500, 13) (500,)
# minkowski 132 uniform
# (500, 13) (500,)
# manhattan 132 uniform
# (500, 13) (500,)
# euclidean 132 uniform
# (500, 13) (500,)
# chebyshev 133 uniform
# (500, 13) (500,)
# minkowski 133 uniform
# (500, 13) (500,)
# manhattan 133 uniform
# (500, 13) (500,)
# euclidean 133 uniform
# (500, 13) (500,)
# chebyshev 134 uniform
# (500, 13) (500,)
# minkowski 134 uniform
# (500, 13) (500,)
# manhattan 134 uniform
# (500, 13) (500,)
# euclidean 134 uniform
# (500, 13) (500,)
# chebyshev 135 uniform
# (500, 13) (500,)
# minkowski 135 uniform
# (500, 13) (500,)
# manhattan 135 uniform
# (500, 13) (500,)
# euclidean 135 uniform
# (500, 13) (500,)
# chebyshev 136 uniform
# (500, 13) (500,)
# minkowski 136 uniform
# (500, 13) (500,)
# manhattan 136 uniform
# (500, 13) (500,)
# euclidean 136 uniform
# (500, 13) (500,)
# chebyshev 137 uniform
# (500, 13) (500,)
# minkowski 137 uniform
# (500, 13) (500,)
# manhattan 137 uniform
# (500, 13) (500,)
# euclidean 137 uniform
# (500, 13) (500,)
# chebyshev 138 uniform
# (500, 13) (500,)
# minkowski 138 uniform
# (500, 13) (500,)
# manhattan 138 uniform
# (500, 13) (500,)
# euclidean 138 uniform
# (500, 13) (500,)
# chebyshev 139 uniform
# (500, 13) (500,)
# minkowski 139 uniform
# (500, 13) (500,)
# manhattan 139 uniform
# (500, 13) (500,)
# euclidean 139 uniform
# (500, 13) (500,)
# chebyshev 140 uniform
# (500, 13) (500,)
# minkowski 140 uniform
# (500, 13) (500,)
# manhattan 140 uniform
# (500, 13) (500,)
# euclidean 140 uniform
# (500, 13) (500,)
# chebyshev 141 uniform
# (500, 13) (500,)
# minkowski 141 uniform
# (500, 13) (500,)
# manhattan 141 uniform
# (500, 13) (500,)
# euclidean 141 uniform
# (500, 13) (500,)
# chebyshev 142 uniform
# (500, 13) (500,)
# minkowski 142 uniform
# (500, 13) (500,)
# manhattan 142 uniform
# (500, 13) (500,)
# euclidean 142 uniform
# (500, 13) (500,)
# chebyshev 143 uniform
# (500, 13) (500,)
# minkowski 143 uniform
# (500, 13) (500,)
# manhattan 143 uniform
# (500, 13) (500,)
# euclidean 143 uniform
# (500, 13) (500,)
# chebyshev 144 uniform
# (500, 13) (500,)
# minkowski 144 uniform
# (500, 13) (500,)
# manhattan 144 uniform
# (500, 13) (500,)
# euclidean 144 uniform
# (500, 13) (500,)
# chebyshev 145 uniform
# (500, 13) (500,)
# minkowski 145 uniform
# (500, 13) (500,)
# manhattan 145 uniform
# (500, 13) (500,)
# euclidean 145 uniform
# (500, 13) (500,)
# chebyshev 146 uniform
# (500, 13) (500,)
# minkowski 146 uniform
# (500, 13) (500,)
# manhattan 146 uniform
# (500, 13) (500,)
# euclidean 146 uniform
# (500, 13) (500,)
# chebyshev 147 uniform
# (500, 13) (500,)
# minkowski 147 uniform
# (500, 13) (500,)
# manhattan 147 uniform
# (500, 13) (500,)
# euclidean 147 uniform
# (500, 13) (500,)
# chebyshev 148 uniform
# (500, 13) (500,)
# minkowski 148 uniform
# (500, 13) (500,)
# manhattan 148 uniform
# (500, 13) (500,)
# euclidean 148 uniform
# (500, 13) (500,)
# chebyshev 149 uniform
# (500, 13) (500,)
# minkowski 149 uniform
# (500, 13) (500,)
# manhattan 149 uniform
# (500, 13) (500,)
# euclidean 149 uniform
# (500, 13) (500,)
# chebyshev 150 uniform
# (500, 13) (500,)
# minkowski 150 uniform
# (500, 13) (500,)
# manhattan 150 uniform
# (500, 13) (500,)
# euclidean 150 uniform
# (500, 13) (500,)
# chebyshev 151 uniform
# (500, 13) (500,)
# minkowski 151 uniform
# (500, 13) (500,)
# manhattan 151 uniform
# (500, 13) (500,)
# euclidean 151 uniform
# (500, 13) (500,)
# chebyshev 152 uniform
# (500, 13) (500,)
# minkowski 152 uniform
# (500, 13) (500,)
# manhattan 152 uniform
# (500, 13) (500,)
# euclidean 152 uniform
# (500, 13) (500,)
# chebyshev 153 uniform
# (500, 13) (500,)
# minkowski 153 uniform
# (500, 13) (500,)
# manhattan 153 uniform
# (500, 13) (500,)
# euclidean 153 uniform
# (500, 13) (500,)
# chebyshev 154 uniform
# (500, 13) (500,)
# minkowski 154 uniform
# (500, 13) (500,)
# manhattan 154 uniform
# (500, 13) (500,)
# euclidean 154 uniform
# (500, 13) (500,)
# chebyshev 155 uniform
# (500, 13) (500,)
# minkowski 155 uniform
# (500, 13) (500,)
# manhattan 155 uniform
# (500, 13) (500,)
# euclidean 155 uniform
# (500, 13) (500,)
# chebyshev 156 uniform
# (500, 13) (500,)
# minkowski 156 uniform
# (500, 13) (500,)
# manhattan 156 uniform
# (500, 13) (500,)
# euclidean 156 uniform
# (500, 13) (500,)
# chebyshev 157 uniform
# (500, 13) (500,)
# minkowski 157 uniform
# (500, 13) (500,)
# manhattan 157 uniform
# (500, 13) (500,)
# euclidean 157 uniform
# (500, 13) (500,)
# chebyshev 158 uniform
# (500, 13) (500,)
# minkowski 158 uniform
# (500, 13) (500,)
# manhattan 158 uniform
# (500, 13) (500,)
# euclidean 158 uniform
# (500, 13) (500,)
# chebyshev 159 uniform
# (500, 13) (500,)
# minkowski 159 uniform
# (500, 13) (500,)
# manhattan 159 uniform
# (500, 13) (500,)
# euclidean 159 uniform
# (500, 13) (500,)
# chebyshev 160 uniform
# (500, 13) (500,)
# minkowski 160 uniform
# (500, 13) (500,)
# manhattan 160 uniform
# (500, 13) (500,)
# euclidean 160 uniform
# (500, 13) (500,)
# chebyshev 161 uniform
# (500, 13) (500,)
# minkowski 161 uniform
# (500, 13) (500,)
# manhattan 161 uniform
# (500, 13) (500,)
# euclidean 161 uniform
# (500, 13) (500,)
# chebyshev 162 uniform
# (500, 13) (500,)
# minkowski 162 uniform
# (500, 13) (500,)
# manhattan 162 uniform
# (500, 13) (500,)
# euclidean 162 uniform
# (500, 13) (500,)
# chebyshev 163 uniform
# (500, 13) (500,)
# minkowski 163 uniform
# (500, 13) (500,)
# manhattan 163 uniform
# (500, 13) (500,)
# euclidean 163 uniform
# (500, 13) (500,)
# chebyshev 164 uniform
# (500, 13) (500,)
# minkowski 164 uniform
# (500, 13) (500,)
# manhattan 164 uniform
# (500, 13) (500,)
# euclidean 164 uniform
# (500, 13) (500,)
# chebyshev 165 uniform
# (500, 13) (500,)
# minkowski 165 uniform
# (500, 13) (500,)
# manhattan 165 uniform
# (500, 13) (500,)
# euclidean 165 uniform
# (500, 13) (500,)
# chebyshev 166 uniform
# (500, 13) (500,)
# minkowski 166 uniform
# (500, 13) (500,)
# manhattan 166 uniform
# (500, 13) (500,)
# euclidean 166 uniform
# (500, 13) (500,)
# chebyshev 167 uniform
# (500, 13) (500,)
# minkowski 167 uniform
# (500, 13) (500,)
# manhattan 167 uniform
# (500, 13) (500,)
# euclidean 167 uniform
# (500, 13) (500,)
# chebyshev 168 uniform
# (500, 13) (500,)
# minkowski 168 uniform
# (500, 13) (500,)
# manhattan 168 uniform
# (500, 13) (500,)
# euclidean 168 uniform
# (500, 13) (500,)
# chebyshev 169 uniform
# (500, 13) (500,)
# minkowski 169 uniform
# (500, 13) (500,)
# manhattan 169 uniform
# (500, 13) (500,)
# euclidean 169 uniform
# (500, 13) (500,)
# chebyshev 170 uniform
# (500, 13) (500,)
# minkowski 170 uniform
# (500, 13) (500,)
# manhattan 170 uniform
# (500, 13) (500,)
# euclidean 170 uniform
# (500, 13) (500,)
# chebyshev 171 uniform
# (500, 13) (500,)
# minkowski 171 uniform
# (500, 13) (500,)
# manhattan 171 uniform
# (500, 13) (500,)
# euclidean 171 uniform
# (500, 13) (500,)
# chebyshev 172 uniform
# (500, 13) (500,)
# minkowski 172 uniform
# (500, 13) (500,)
# manhattan 172 uniform
# (500, 13) (500,)
# euclidean 172 uniform
# (500, 13) (500,)
# chebyshev 173 uniform
# (500, 13) (500,)
# minkowski 173 uniform
# (500, 13) (500,)
# manhattan 173 uniform
# (500, 13) (500,)
# euclidean 173 uniform
# (500, 13) (500,)
# chebyshev 174 uniform
# (500, 13) (500,)
# minkowski 174 uniform
# (500, 13) (500,)
# manhattan 174 uniform
# (500, 13) (500,)
# euclidean 174 uniform
# (500, 13) (500,)
# chebyshev 175 uniform
# (500, 13) (500,)
# minkowski 175 uniform
# (500, 13) (500,)
# manhattan 175 uniform
# (500, 13) (500,)
# euclidean 175 uniform
# (500, 13) (500,)
# chebyshev 176 uniform
# (500, 13) (500,)
# minkowski 176 uniform
# (500, 13) (500,)
# manhattan 176 uniform
# (500, 13) (500,)
# euclidean 176 uniform
# (500, 13) (500,)
# chebyshev 177 uniform
# (500, 13) (500,)
# minkowski 177 uniform
# (500, 13) (500,)
# manhattan 177 uniform
# (500, 13) (500,)
# euclidean 177 uniform
# (500, 13) (500,)
# chebyshev 178 uniform
# (500, 13) (500,)
# minkowski 178 uniform
# (500, 13) (500,)
# manhattan 178 uniform
# (500, 13) (500,)
# euclidean 178 uniform
# (500, 13) (500,)
# chebyshev 179 uniform
# (500, 13) (500,)
# minkowski 179 uniform
# (500, 13) (500,)
# manhattan 179 uniform
# (500, 13) (500,)
# euclidean 179 uniform
# (500, 13) (500,)
# chebyshev 180 uniform
# (500, 13) (500,)
# minkowski 180 uniform
# (500, 13) (500,)
# manhattan 180 uniform
# (500, 13) (500,)
# euclidean 180 uniform
# (500, 13) (500,)
# chebyshev 181 uniform
# (500, 13) (500,)
# minkowski 181 uniform
# (500, 13) (500,)
# manhattan 181 uniform
# (500, 13) (500,)
# euclidean 181 uniform
# (500, 13) (500,)
# chebyshev 182 uniform
# (500, 13) (500,)
# minkowski 182 uniform
# (500, 13) (500,)
# manhattan 182 uniform
# (500, 13) (500,)
# euclidean 182 uniform
# (500, 13) (500,)
# chebyshev 183 uniform
# (500, 13) (500,)
# minkowski 183 uniform
# (500, 13) (500,)
# manhattan 183 uniform
# (500, 13) (500,)
# euclidean 183 uniform
# (500, 13) (500,)
# chebyshev 184 uniform
# (500, 13) (500,)
# minkowski 184 uniform
# (500, 13) (500,)
# manhattan 184 uniform
# (500, 13) (500,)
# euclidean 184 uniform
# (500, 13) (500,)
# chebyshev 185 uniform
# (500, 13) (500,)
# minkowski 185 uniform
# (500, 13) (500,)
# manhattan 185 uniform
# (500, 13) (500,)
# euclidean 185 uniform
# (500, 13) (500,)
# chebyshev 186 uniform
# (500, 13) (500,)
# minkowski 186 uniform
# (500, 13) (500,)
# manhattan 186 uniform
# (500, 13) (500,)
# euclidean 186 uniform
# (500, 13) (500,)
# chebyshev 187 uniform
# (500, 13) (500,)
# minkowski 187 uniform
# (500, 13) (500,)
# manhattan 187 uniform
# (500, 13) (500,)
# euclidean 187 uniform
# (500, 13) (500,)
# chebyshev 188 uniform
# (500, 13) (500,)
# minkowski 188 uniform
# (500, 13) (500,)
# manhattan 188 uniform
# (500, 13) (500,)
# euclidean 188 uniform
# (500, 13) (500,)
# chebyshev 189 uniform
# (500, 13) (500,)
# minkowski 189 uniform
# (500, 13) (500,)
# manhattan 189 uniform
# (500, 13) (500,)
# euclidean 189 uniform
# (500, 13) (500,)
# chebyshev 190 uniform
# (500, 13) (500,)
# minkowski 190 uniform
# (500, 13) (500,)
# manhattan 190 uniform
# (500, 13) (500,)
# euclidean 190 uniform
# (500, 13) (500,)
# chebyshev 191 uniform
# (500, 13) (500,)
# minkowski 191 uniform
# (500, 13) (500,)
# manhattan 191 uniform
# (500, 13) (500,)
# euclidean 191 uniform
# (500, 13) (500,)
# chebyshev 192 uniform
# (500, 13) (500,)
# minkowski 192 uniform
# (500, 13) (500,)
# manhattan 192 uniform
# (500, 13) (500,)
# euclidean 192 uniform
# (500, 13) (500,)
# chebyshev 193 uniform
# (500, 13) (500,)
# minkowski 193 uniform
# (500, 13) (500,)
# manhattan 193 uniform
# (500, 13) (500,)
# euclidean 193 uniform
# (500, 13) (500,)
# chebyshev 194 uniform
# (500, 13) (500,)
# minkowski 194 uniform
# (500, 13) (500,)
# manhattan 194 uniform
# (500, 13) (500,)
# euclidean 194 uniform
# (500, 13) (500,)
# chebyshev 195 uniform
# (500, 13) (500,)
# minkowski 195 uniform
# (500, 13) (500,)
# manhattan 195 uniform
# (500, 13) (500,)
# euclidean 195 uniform
# (500, 13) (500,)
# chebyshev 196 uniform
# (500, 13) (500,)
# minkowski 196 uniform
# (500, 13) (500,)
# manhattan 196 uniform
# (500, 13) (500,)
# euclidean 196 uniform
# (500, 13) (500,)
# chebyshev 197 uniform
# (500, 13) (500,)
# minkowski 197 uniform
# (500, 13) (500,)
# manhattan 197 uniform
# (500, 13) (500,)
# euclidean 197 uniform
# (500, 13) (500,)
# chebyshev 198 uniform
# (500, 13) (500,)
# minkowski 198 uniform
# (500, 13) (500,)
# manhattan 198 uniform
# (500, 13) (500,)
# euclidean 198 uniform
# (500, 13) (500,)
# chebyshev 199 uniform
# (500, 13) (500,)
# minkowski 199 uniform
# (500, 13) (500,)
# manhattan 199 uniform
# (500, 13) (500,)
# euclidean 199 uniform
# (500, 13) (500,)
# chebyshev 200 uniform
# (500, 13) (500,)
# minkowski 200 uniform
# (500, 13) (500,)
# manhattan 200 uniform
# (500, 13) (500,)
# euclidean 200 uniform
# (500, 13) (500,)
# chebyshev 201 uniform
# (500, 13) (500,)
# minkowski 201 uniform
# (500, 13) (500,)
# manhattan 201 uniform
# (500, 13) (500,)
# euclidean 201 uniform
# (500, 13) (500,)
# chebyshev 202 uniform
# (500, 13) (500,)
# minkowski 202 uniform
# (500, 13) (500,)
# manhattan 202 uniform
# (500, 13) (500,)
# euclidean 202 uniform
# (500, 13) (500,)
# chebyshev 203 uniform
# (500, 13) (500,)
# minkowski 203 uniform
# (500, 13) (500,)
# manhattan 203 uniform
# (500, 13) (500,)
# euclidean 203 uniform
# (500, 13) (500,)
# chebyshev 204 uniform
# (500, 13) (500,)
# minkowski 204 uniform
# (500, 13) (500,)
# manhattan 204 uniform
# (500, 13) (500,)
# euclidean 204 uniform
# (500, 13) (500,)
# chebyshev 205 uniform
# (500, 13) (500,)
# minkowski 205 uniform
# (500, 13) (500,)
# manhattan 205 uniform
# (500, 13) (500,)
# euclidean 205 uniform
# (500, 13) (500,)
# chebyshev 206 uniform
# (500, 13) (500,)
# minkowski 206 uniform
# (500, 13) (500,)
# manhattan 206 uniform
# (500, 13) (500,)
# euclidean 206 uniform
# (500, 13) (500,)
# chebyshev 207 uniform
# (500, 13) (500,)
# minkowski 207 uniform
# (500, 13) (500,)
# manhattan 207 uniform
# (500, 13) (500,)
# euclidean 207 uniform
# (500, 13) (500,)
# chebyshev 208 uniform
# (500, 13) (500,)
# minkowski 208 uniform
# (500, 13) (500,)
# manhattan 208 uniform
# (500, 13) (500,)
# euclidean 208 uniform
# (500, 13) (500,)
# chebyshev 209 uniform
# (500, 13) (500,)
# minkowski 209 uniform
# (500, 13) (500,)
# manhattan 209 uniform
# (500, 13) (500,)
# euclidean 209 uniform
# (500, 13) (500,)
# chebyshev 210 uniform
# (500, 13) (500,)
# minkowski 210 uniform
# (500, 13) (500,)
# manhattan 210 uniform
# (500, 13) (500,)
# euclidean 210 uniform
# (500, 13) (500,)
# chebyshev 211 uniform
# (500, 13) (500,)
# minkowski 211 uniform
# (500, 13) (500,)
# manhattan 211 uniform
# (500, 13) (500,)
# euclidean 211 uniform
# (500, 13) (500,)
# chebyshev 212 uniform
# (500, 13) (500,)
# minkowski 212 uniform
# (500, 13) (500,)
# manhattan 212 uniform
# (500, 13) (500,)
# euclidean 212 uniform
# (500, 13) (500,)
# chebyshev 213 uniform
# (500, 13) (500,)
# minkowski 213 uniform
# (500, 13) (500,)
# manhattan 213 uniform
# (500, 13) (500,)
# euclidean 213 uniform
# (500, 13) (500,)
# chebyshev 214 uniform
# (500, 13) (500,)
# minkowski 214 uniform
# (500, 13) (500,)
# manhattan 214 uniform
# (500, 13) (500,)
# euclidean 214 uniform
# (500, 13) (500,)
# chebyshev 215 uniform
# (500, 13) (500,)
# minkowski 215 uniform
# (500, 13) (500,)
# manhattan 215 uniform
# (500, 13) (500,)
# euclidean 215 uniform
# (500, 13) (500,)
# chebyshev 216 uniform
# (500, 13) (500,)
# minkowski 216 uniform
# (500, 13) (500,)
# manhattan 216 uniform
# (500, 13) (500,)
# euclidean 216 uniform
# (500, 13) (500,)
# chebyshev 217 uniform
# (500, 13) (500,)
# minkowski 217 uniform
# (500, 13) (500,)
# manhattan 217 uniform
# (500, 13) (500,)
# euclidean 217 uniform
# (500, 13) (500,)
# chebyshev 218 uniform
# (500, 13) (500,)
# minkowski 218 uniform
# (500, 13) (500,)
# manhattan 218 uniform
# (500, 13) (500,)
# euclidean 218 uniform
# (500, 13) (500,)
# chebyshev 219 uniform
# (500, 13) (500,)
# minkowski 219 uniform
# (500, 13) (500,)
# manhattan 219 uniform
# (500, 13) (500,)
# euclidean 219 uniform
# (500, 13) (500,)
# chebyshev 220 uniform
# (500, 13) (500,)
# minkowski 220 uniform
# (500, 13) (500,)
# manhattan 220 uniform
# (500, 13) (500,)
# euclidean 220 uniform
# (500, 13) (500,)
# chebyshev 221 uniform
# (500, 13) (500,)
# minkowski 221 uniform
# (500, 13) (500,)
# manhattan 221 uniform
# (500, 13) (500,)
# euclidean 221 uniform
# (500, 13) (500,)
# chebyshev 222 uniform
# (500, 13) (500,)
# minkowski 222 uniform
# (500, 13) (500,)
# manhattan 222 uniform
# (500, 13) (500,)
# euclidean 222 uniform
# (500, 13) (500,)
# chebyshev 223 uniform
# (500, 13) (500,)
# minkowski 223 uniform
# (500, 13) (500,)
# manhattan 223 uniform
# (500, 13) (500,)
# euclidean 223 uniform
# (500, 13) (500,)
# chebyshev 224 uniform
# (500, 13) (500,)
# minkowski 224 uniform
# (500, 13) (500,)
# manhattan 224 uniform
# (500, 13) (500,)
# euclidean 224 uniform
# (500, 13) (500,)
# chebyshev 225 uniform
# (500, 13) (500,)
# minkowski 225 uniform
# (500, 13) (500,)
# manhattan 225 uniform
# (500, 13) (500,)
# euclidean 225 uniform
# (500, 13) (500,)
# chebyshev 226 uniform
# (500, 13) (500,)
# minkowski 226 uniform
# (500, 13) (500,)
# manhattan 226 uniform
# (500, 13) (500,)
# euclidean 226 uniform
# (500, 13) (500,)
# chebyshev 227 uniform
# (500, 13) (500,)
# minkowski 227 uniform
# (500, 13) (500,)
# manhattan 227 uniform
# (500, 13) (500,)
# euclidean 227 uniform
# (500, 13) (500,)
# chebyshev 228 uniform
# (500, 13) (500,)
# minkowski 228 uniform
# (500, 13) (500,)
# manhattan 228 uniform
# (500, 13) (500,)
# euclidean 228 uniform
# (500, 13) (500,)
# chebyshev 229 uniform
# (500, 13) (500,)
# minkowski 229 uniform
# (500, 13) (500,)
# manhattan 229 uniform
# (500, 13) (500,)
# euclidean 229 uniform
# (500, 13) (500,)
# chebyshev 230 uniform
# (500, 13) (500,)
# minkowski 230 uniform
# (500, 13) (500,)
# manhattan 230 uniform
# (500, 13) (500,)
# euclidean 230 uniform
# (500, 13) (500,)
# chebyshev 231 uniform
# (500, 13) (500,)
# minkowski 231 uniform
# (500, 13) (500,)
# manhattan 231 uniform
# (500, 13) (500,)
# euclidean 231 uniform
# (500, 13) (500,)
# chebyshev 232 uniform
# (500, 13) (500,)
# minkowski 232 uniform
# (500, 13) (500,)
# manhattan 232 uniform
# (500, 13) (500,)
# euclidean 232 uniform
# (500, 13) (500,)
# chebyshev 233 uniform
# (500, 13) (500,)
# minkowski 233 uniform
# (500, 13) (500,)
# manhattan 233 uniform
# (500, 13) (500,)
# euclidean 233 uniform
# (500, 13) (500,)
# chebyshev 234 uniform
# (500, 13) (500,)
# minkowski 234 uniform
# (500, 13) (500,)
# manhattan 234 uniform
# (500, 13) (500,)
# euclidean 234 uniform
# (500, 13) (500,)
# chebyshev 235 uniform
# (500, 13) (500,)
# minkowski 235 uniform
# (500, 13) (500,)
# manhattan 235 uniform
# (500, 13) (500,)
# euclidean 235 uniform
# (500, 13) (500,)
# chebyshev 236 uniform
# (500, 13) (500,)
# minkowski 236 uniform
# (500, 13) (500,)
# manhattan 236 uniform
# (500, 13) (500,)
# euclidean 236 uniform
# (500, 13) (500,)
# chebyshev 237 uniform
# (500, 13) (500,)
# minkowski 237 uniform
# (500, 13) (500,)
# manhattan 237 uniform
# (500, 13) (500,)
# euclidean 237 uniform
# (500, 13) (500,)
# chebyshev 238 uniform
# (500, 13) (500,)
# minkowski 238 uniform
# (500, 13) (500,)
# manhattan 238 uniform
# (500, 13) (500,)
# euclidean 238 uniform
# (500, 13) (500,)
# chebyshev 239 uniform
# (500, 13) (500,)
# minkowski 239 uniform
# (500, 13) (500,)
# manhattan 239 uniform
# (500, 13) (500,)
# euclidean 239 uniform
# (500, 13) (500,)
# chebyshev 240 uniform
# (500, 13) (500,)
# minkowski 240 uniform
# (500, 13) (500,)
# manhattan 240 uniform
# (500, 13) (500,)
# euclidean 240 uniform
# (500, 13) (500,)
# chebyshev 241 uniform
# (500, 13) (500,)
# minkowski 241 uniform
# (500, 13) (500,)
# manhattan 241 uniform
# (500, 13) (500,)
# euclidean 241 uniform
# (500, 13) (500,)
# chebyshev 242 uniform
# (500, 13) (500,)
# minkowski 242 uniform
# (500, 13) (500,)
# manhattan 242 uniform
# (500, 13) (500,)
# euclidean 242 uniform
# (500, 13) (500,)
# chebyshev 243 uniform
# (500, 13) (500,)
# minkowski 243 uniform
# (500, 13) (500,)
# manhattan 243 uniform
# (500, 13) (500,)
# euclidean 243 uniform
# (500, 13) (500,)
# chebyshev 244 uniform
# (500, 13) (500,)
# minkowski 244 uniform
# (500, 13) (500,)
# manhattan 244 uniform
# (500, 13) (500,)
# euclidean 244 uniform
# (500, 13) (500,)
# chebyshev 245 uniform
# (500, 13) (500,)
# minkowski 245 uniform
# (500, 13) (500,)
# manhattan 245 uniform
# (500, 13) (500,)
# euclidean 245 uniform
# (500, 13) (500,)
# chebyshev 246 uniform
# (500, 13) (500,)
# minkowski 246 uniform
# (500, 13) (500,)
# manhattan 246 uniform
# (500, 13) (500,)
# euclidean 246 uniform
# (500, 13) (500,)
# chebyshev 247 uniform
# (500, 13) (500,)
# minkowski 247 uniform
# (500, 13) (500,)
# manhattan 247 uniform
# (500, 13) (500,)
# euclidean 247 uniform
# (500, 13) (500,)
# chebyshev 248 uniform
# (500, 13) (500,)
# minkowski 248 uniform
# (500, 13) (500,)
# manhattan 248 uniform
# (500, 13) (500,)
# euclidean 248 uniform
# (500, 13) (500,)
# chebyshev 249 uniform
# (500, 13) (500,)
# minkowski 249 uniform
# (500, 13) (500,)
# manhattan 249 uniform
# (500, 13) (500,)
# euclidean 249 uniform
# (500, 13) (500,)
# chebyshev 250 uniform
# (500, 13) (500,)
# minkowski 250 uniform
# (500, 13) (500,)
# manhattan 250 uniform
# (500, 13) (500,)
# euclidean 250 uniform
# (500, 13) (500,)
# chebyshev 251 uniform
# (500, 13) (500,)
# minkowski 251 uniform
# (500, 13) (500,)
# manhattan 251 uniform
# (500, 13) (500,)
# euclidean 251 uniform
# (500, 13) (500,)
# chebyshev 252 uniform
# (500, 13) (500,)
# minkowski 252 uniform
# (500, 13) (500,)
# manhattan 252 uniform
# (500, 13) (500,)
# euclidean 252 uniform
# (500, 13) (500,)
# chebyshev 253 uniform
# (500, 13) (500,)
# minkowski 253 uniform
# (500, 13) (500,)
# manhattan 253 uniform
# (500, 13) (500,)
# euclidean 253 uniform
# (500, 13) (500,)
# chebyshev 254 uniform
# (500, 13) (500,)
# minkowski 254 uniform
# (500, 13) (500,)
# manhattan 254 uniform
# (500, 13) (500,)
# euclidean 254 uniform
# (500, 13) (500,)
# chebyshev 255 uniform
# (500, 13) (500,)
# minkowski 255 uniform
# (500, 13) (500,)
# manhattan 255 uniform
# (500, 13) (500,)
# euclidean 255 uniform
# (500, 13) (500,)
# chebyshev 256 uniform
# (500, 13) (500,)
# minkowski 256 uniform
# (500, 13) (500,)
# manhattan 256 uniform
# (500, 13) (500,)
# euclidean 256 uniform
# (500, 13) (500,)
# chebyshev 257 uniform
# (500, 13) (500,)
# minkowski 257 uniform
# (500, 13) (500,)
# manhattan 257 uniform
# (500, 13) (500,)
# euclidean 257 uniform
# (500, 13) (500,)
# chebyshev 258 uniform
# (500, 13) (500,)
# minkowski 258 uniform
# (500, 13) (500,)
# manhattan 258 uniform
# (500, 13) (500,)
# euclidean 258 uniform
# (500, 13) (500,)
# chebyshev 259 uniform
# (500, 13) (500,)
# minkowski 259 uniform
# (500, 13) (500,)
# manhattan 259 uniform
# (500, 13) (500,)
# euclidean 259 uniform
# (500, 13) (500,)
# chebyshev 260 uniform
# (500, 13) (500,)
# minkowski 260 uniform
# (500, 13) (500,)
# manhattan 260 uniform
# (500, 13) (500,)
# euclidean 260 uniform
# (500, 13) (500,)
# chebyshev 261 uniform
# (500, 13) (500,)
# minkowski 261 uniform
# (500, 13) (500,)
# manhattan 261 uniform
# (500, 13) (500,)
# euclidean 261 uniform
# (500, 13) (500,)
# chebyshev 262 uniform
# (500, 13) (500,)
# minkowski 262 uniform
# (500, 13) (500,)
# manhattan 262 uniform
# (500, 13) (500,)
# euclidean 262 uniform
# (500, 13) (500,)
# chebyshev 263 uniform
# (500, 13) (500,)
# minkowski 263 uniform
# (500, 13) (500,)
# manhattan 263 uniform
# (500, 13) (500,)
# euclidean 263 uniform
# (500, 13) (500,)
# chebyshev 264 uniform
# (500, 13) (500,)
# minkowski 264 uniform
# (500, 13) (500,)
# manhattan 264 uniform
# (500, 13) (500,)
# euclidean 264 uniform
# (500, 13) (500,)
# chebyshev 265 uniform
# (500, 13) (500,)
# minkowski 265 uniform
# (500, 13) (500,)
# manhattan 265 uniform
# (500, 13) (500,)
# euclidean 265 uniform
# (500, 13) (500,)
# chebyshev 266 uniform
# (500, 13) (500,)
# minkowski 266 uniform
# (500, 13) (500,)
# manhattan 266 uniform
# (500, 13) (500,)
# euclidean 266 uniform
# (500, 13) (500,)
# chebyshev 267 uniform
# (500, 13) (500,)
# minkowski 267 uniform
# (500, 13) (500,)
# manhattan 267 uniform
# (500, 13) (500,)
# euclidean 267 uniform
# (500, 13) (500,)
# chebyshev 268 uniform
# (500, 13) (500,)
# minkowski 268 uniform
# (500, 13) (500,)
# manhattan 268 uniform
# (500, 13) (500,)
# euclidean 268 uniform
# (500, 13) (500,)
# chebyshev 269 uniform
# (500, 13) (500,)
# minkowski 269 uniform
# (500, 13) (500,)
# manhattan 269 uniform
# (500, 13) (500,)
# euclidean 269 uniform
# (500, 13) (500,)
# chebyshev 270 uniform
# (500, 13) (500,)
# minkowski 270 uniform
# (500, 13) (500,)
# manhattan 270 uniform
# (500, 13) (500,)
# euclidean 270 uniform
# (500, 13) (500,)
# chebyshev 271 uniform
# (500, 13) (500,)
# minkowski 271 uniform
# (500, 13) (500,)
# manhattan 271 uniform
# (500, 13) (500,)
# euclidean 271 uniform
# (500, 13) (500,)
# chebyshev 272 uniform
# (500, 13) (500,)
# minkowski 272 uniform
# (500, 13) (500,)
# manhattan 272 uniform
# (500, 13) (500,)
# euclidean 272 uniform
# (500, 13) (500,)
# chebyshev 273 uniform
# (500, 13) (500,)
# minkowski 273 uniform
# (500, 13) (500,)
# manhattan 273 uniform
# (500, 13) (500,)
# euclidean 273 uniform
# (500, 13) (500,)
# chebyshev 274 uniform
# (500, 13) (500,)
# minkowski 274 uniform
# (500, 13) (500,)
# manhattan 274 uniform
# (500, 13) (500,)
# euclidean 274 uniform
# (500, 13) (500,)
# chebyshev 275 uniform
# (500, 13) (500,)
# minkowski 275 uniform
# (500, 13) (500,)
# manhattan 275 uniform
# (500, 13) (500,)
# euclidean 275 uniform
# (500, 13) (500,)
# chebyshev 276 uniform
# (500, 13) (500,)
# minkowski 276 uniform
# (500, 13) (500,)
# manhattan 276 uniform
# (500, 13) (500,)
# euclidean 276 uniform
# (500, 13) (500,)
# chebyshev 277 uniform
# (500, 13) (500,)
# minkowski 277 uniform
# (500, 13) (500,)
# manhattan 277 uniform
# (500, 13) (500,)
# euclidean 277 uniform
# (500, 13) (500,)
# chebyshev 278 uniform
# (500, 13) (500,)
# minkowski 278 uniform
# (500, 13) (500,)
# manhattan 278 uniform
# (500, 13) (500,)
# euclidean 278 uniform
# (500, 13) (500,)
# chebyshev 279 uniform
# (500, 13) (500,)
# minkowski 279 uniform
# (500, 13) (500,)
# manhattan 279 uniform
# (500, 13) (500,)
# euclidean 279 uniform
# (500, 13) (500,)
# chebyshev 280 uniform
# (500, 13) (500,)
# minkowski 280 uniform
# (500, 13) (500,)
# manhattan 280 uniform
# (500, 13) (500,)
# euclidean 280 uniform
# (500, 13) (500,)
# chebyshev 281 uniform
# (500, 13) (500,)
# minkowski 281 uniform
# (500, 13) (500,)
# manhattan 281 uniform
# (500, 13) (500,)
# euclidean 281 uniform
# (500, 13) (500,)
# chebyshev 282 uniform
# (500, 13) (500,)
# minkowski 282 uniform
# (500, 13) (500,)
# manhattan 282 uniform
# (500, 13) (500,)
# euclidean 282 uniform
# (500, 13) (500,)
# chebyshev 283 uniform
# (500, 13) (500,)
# minkowski 283 uniform
# (500, 13) (500,)
# manhattan 283 uniform
# (500, 13) (500,)
# euclidean 283 uniform
# (500, 13) (500,)
# chebyshev 284 uniform
# (500, 13) (500,)
# minkowski 284 uniform
# (500, 13) (500,)
# manhattan 284 uniform
# (500, 13) (500,)
# euclidean 284 uniform
# (500, 13) (500,)
# chebyshev 285 uniform
# (500, 13) (500,)
# minkowski 285 uniform
# (500, 13) (500,)
# manhattan 285 uniform
# (500, 13) (500,)
# euclidean 285 uniform
# (500, 13) (500,)
# chebyshev 286 uniform
# (500, 13) (500,)
# minkowski 286 uniform
# (500, 13) (500,)
# manhattan 286 uniform
# (500, 13) (500,)
# euclidean 286 uniform
# (500, 13) (500,)
# chebyshev 287 uniform
# (500, 13) (500,)
# minkowski 287 uniform
# (500, 13) (500,)
# manhattan 287 uniform
# (500, 13) (500,)
# euclidean 287 uniform
# (500, 13) (500,)
# chebyshev 288 uniform
# (500, 13) (500,)
# minkowski 288 uniform
# (500, 13) (500,)
# manhattan 288 uniform
# (500, 13) (500,)
# euclidean 288 uniform
# (500, 13) (500,)
# chebyshev 289 uniform
# (500, 13) (500,)
# minkowski 289 uniform
# (500, 13) (500,)
# manhattan 289 uniform
# (500, 13) (500,)
# euclidean 289 uniform
# (500, 13) (500,)
# chebyshev 290 uniform
# (500, 13) (500,)
# minkowski 290 uniform
# (500, 13) (500,)
# manhattan 290 uniform
# (500, 13) (500,)
# euclidean 290 uniform
# (500, 13) (500,)
# chebyshev 291 uniform
# (500, 13) (500,)
# minkowski 291 uniform
# (500, 13) (500,)
# manhattan 291 uniform
# (500, 13) (500,)
# euclidean 291 uniform
# (500, 13) (500,)
# chebyshev 292 uniform
# (500, 13) (500,)
# minkowski 292 uniform
# (500, 13) (500,)
# manhattan 292 uniform
# (500, 13) (500,)
# euclidean 292 uniform
# (500, 13) (500,)
# chebyshev 293 uniform
# (500, 13) (500,)
# minkowski 293 uniform
# (500, 13) (500,)
# manhattan 293 uniform
# (500, 13) (500,)
# euclidean 293 uniform
# (500, 13) (500,)
# chebyshev 294 uniform
# (500, 13) (500,)
# minkowski 294 uniform
# (500, 13) (500,)
# manhattan 294 uniform
# (500, 13) (500,)
# euclidean 294 uniform
# (500, 13) (500,)
# chebyshev 295 uniform
# (500, 13) (500,)
# minkowski 295 uniform
# (500, 13) (500,)
# manhattan 295 uniform
# (500, 13) (500,)
# euclidean 295 uniform
# (500, 13) (500,)
# chebyshev 296 uniform
# (500, 13) (500,)
# minkowski 296 uniform
# (500, 13) (500,)
# manhattan 296 uniform
# (500, 13) (500,)
# euclidean 296 uniform
# (500, 13) (500,)
# chebyshev 297 uniform
# (500, 13) (500,)
# minkowski 297 uniform
# (500, 13) (500,)
# manhattan 297 uniform
# (500, 13) (500,)
# euclidean 297 uniform
# (500, 13) (500,)
# chebyshev 298 uniform
# (500, 13) (500,)
# minkowski 298 uniform
# (500, 13) (500,)
# manhattan 298 uniform
# (500, 13) (500,)
# euclidean 298 uniform
# (500, 13) (500,)
# chebyshev 299 uniform
# (500, 13) (500,)
# minkowski 299 uniform
# (500, 13) (500,)
# manhattan 299 uniform
# (500, 13) (500,)
# euclidean 299 uniform
# (500, 13) (500,)
# chebyshev 300 uniform
# (500, 13) (500,)
# minkowski 300 uniform
# (500, 13) (500,)
# manhattan 300 uniform
# (500, 13) (500,)
# euclidean 300 uniform
# (500, 13) (500,)
# chebyshev 301 uniform
# (500, 13) (500,)
# minkowski 301 uniform
# (500, 13) (500,)
# manhattan 301 uniform
# (500, 13) (500,)
# euclidean 301 uniform
# (500, 13) (500,)
# chebyshev 302 uniform
# (500, 13) (500,)
# minkowski 302 uniform
# (500, 13) (500,)
# manhattan 302 uniform
# (500, 13) (500,)
# euclidean 302 uniform
# (500, 13) (500,)
# chebyshev 303 uniform
# (500, 13) (500,)
# minkowski 303 uniform
# (500, 13) (500,)
# manhattan 303 uniform
# (500, 13) (500,)
# euclidean 303 uniform
# (500, 13) (500,)
# chebyshev 304 uniform
# (500, 13) (500,)
# minkowski 304 uniform
# (500, 13) (500,)
# manhattan 304 uniform
# (500, 13) (500,)
# euclidean 304 uniform
# (500, 13) (500,)
# chebyshev 305 uniform
# (500, 13) (500,)
# minkowski 305 uniform
# (500, 13) (500,)
# manhattan 305 uniform
# (500, 13) (500,)
# euclidean 305 uniform
# (500, 13) (500,)
# chebyshev 306 uniform
# (500, 13) (500,)
# minkowski 306 uniform
# (500, 13) (500,)
# manhattan 306 uniform
# (500, 13) (500,)
# euclidean 306 uniform
# (500, 13) (500,)
# chebyshev 307 uniform
# (500, 13) (500,)
# minkowski 307 uniform
# (500, 13) (500,)
# manhattan 307 uniform
# (500, 13) (500,)
# euclidean 307 uniform
# (500, 13) (500,)
# chebyshev 308 uniform
# (500, 13) (500,)
# minkowski 308 uniform
# (500, 13) (500,)
# manhattan 308 uniform
# (500, 13) (500,)
# euclidean 308 uniform
# (500, 13) (500,)
# chebyshev 309 uniform
# (500, 13) (500,)
# minkowski 309 uniform
# (500, 13) (500,)
# manhattan 309 uniform
# (500, 13) (500,)
# euclidean 309 uniform
# (500, 13) (500,)
# chebyshev 310 uniform
# (500, 13) (500,)
# minkowski 310 uniform
# (500, 13) (500,)
# manhattan 310 uniform
# (500, 13) (500,)
# euclidean 310 uniform
# (500, 13) (500,)
# chebyshev 311 uniform
# (500, 13) (500,)
# minkowski 311 uniform
# ...
# chebyshev 400 distance
# (500, 13) (500,)
# minkowski 400 distance
# (500, 13) (500,)
# manhattan 400 distance
# (500, 13) (500,)
# euclidean 400 distance
# (500, 13) (500,)
# chebyshev 401 distance
# (500, 13) (500,)
# minkowski 401 distance
# (500, 13) (500,)
# manhattan 401 distance
# (500, 13) (500,)
# euclidean 401 distance
# (500, 13) (500,)
# chebyshev 402 distance
# (500, 13) (500,)
# minkowski 402 distance
# (500, 13) (500,)
# manhattan 402 distance
# (500, 13) (500,)
# euclidean 402 distance
# (500, 13) (500,)
# chebyshev 403 distance
# (500, 13) (500,)
# minkowski 403 distance
# (500, 13) (500,)
# manhattan 403 distance
# (500, 13) (500,)
# euclidean 403 distance
# (500, 13) (500,)
# chebyshev 404 distance
# (500, 13) (500,)
# minkowski 404 distance
# (500, 13) (500,)
# manhattan 404 distance
# (500, 13) (500,)
# euclidean 404 distance
# (500, 13) (500,)
# chebyshev 405 distance
# (500, 13) (500,)
# minkowski 405 distance
# (500, 13) (500,)
# manhattan 405 distance
# (500, 13) (500,)
# euclidean 405 distance
# (500, 13) (500,)
# chebyshev 406 distance
# (500, 13) (500,)
# minkowski 406 distance
# (500, 13) (500,)
# manhattan 406 distance
# (500, 13) (500,)
# euclidean 406 distance
# (500, 13) (500,)
# chebyshev 407 distance
# (500, 13) (500,)
# minkowski 407 distance
# (500, 13) (500,)
# manhattan 407 distance
# (500, 13) (500,)
# euclidean 407 distance
# (500, 13) (500,)
# chebyshev 408 distance
# (500, 13) (500,)
# minkowski 408 distance
# (500, 13) (500,)
# manhattan 408 distance
# (500, 13) (500,)
# euclidean 408 distance
# (500, 13) (500,)
# chebyshev 409 distance
# (500, 13) (500,)
# minkowski 409 distance
# (500, 13) (500,)
# manhattan 409 distance
# (500, 13) (500,)
# euclidean 409 distance
# (500, 13) (500,)
# chebyshev 410 distance
# (500, 13) (500,)
# minkowski 410 distance
# (500, 13) (500,)
# manhattan 410 distance
# (500, 13) (500,)
# euclidean 410 distance
# (500, 13) (500,)
# chebyshev 411 distance
# (500, 13) (500,)
# minkowski 411 distance
# (500, 13) (500,)
# manhattan 411 distance
# (500, 13) (500,)
# euclidean 411 distance
# (500, 13) (500,)
# chebyshev 412 distance
# (500, 13) (500,)
# minkowski 412 distance
# (500, 13) (500,)
# manhattan 412 distance
# (500, 13) (500,)
# euclidean 412 distance
# (500, 13) (500,)
# chebyshev 413 distance
# (500, 13) (500,)
# minkowski 413 distance
# (500, 13) (500,)
# manhattan 413 distance
# (500, 13) (500,)
# euclidean 413 distance
# (500, 13) (500,)
# chebyshev 414 distance
# (500, 13) (500,)
# minkowski 414 distance
# (500, 13) (500,)
# manhattan 414 distance
# (500, 13) (500,)
# euclidean 414 distance
# (500, 13) (500,)
# chebyshev 415 distance
# (500, 13) (500,)
# minkowski 415 distance
# (500, 13) (500,)
# manhattan 415 distance
# (500, 13) (500,)
# euclidean 415 distance
# (500, 13) (500,)
# chebyshev 416 distance
# (500, 13) (500,)
# minkowski 416 distance
# (500, 13) (500,)
# manhattan 416 distance
# (500, 13) (500,)
# euclidean 416 distance
# (500, 13) (500,)
# chebyshev 417 distance
# (500, 13) (500,)
# minkowski 417 distance
# (500, 13) (500,)
# manhattan 417 distance
# (500, 13) (500,)
# euclidean 417 distance
# (500, 13) (500,)
# chebyshev 418 distance
# (500, 13) (500,)
# minkowski 418 distance
# (500, 13) (500,)
# manhattan 418 distance
# (500, 13) (500,)
# euclidean 418 distance
# (500, 13) (500,)
# chebyshev 419 distance
# (500, 13) (500,)
# minkowski 419 distance
# (500, 13) (500,)
# manhattan 419 distance
# (500, 13) (500,)
# euclidean 419 distance
# (500, 13) (500,)
# chebyshev 420 distance
# (500, 13) (500,)
# minkowski 420 distance
# (500, 13) (500,)
# manhattan 420 distance
# (500, 13) (500,)
# euclidean 420 distance
# (500, 13) (500,)
# chebyshev 421 distance
# (500, 13) (500,)
# minkowski 421 distance
# (500, 13) (500,)
# manhattan 421 distance
# (500, 13) (500,)
# euclidean 421 distance
# (500, 13) (500,)
# chebyshev 422 distance
# (500, 13) (500,)
# minkowski 422 distance
# (500, 13) (500,)
# manhattan 422 distance
# (500, 13) (500,)
# euclidean 422 distance
# (500, 13) (500,)
# chebyshev 423 distance
# (500, 13) (500,)
# minkowski 423 distance
# (500, 13) (500,)
# manhattan 423 distance
# (500, 13) (500,)
# euclidean 423 distance
# (500, 13) (500,)
# chebyshev 424 distance
# (500, 13) (500,)
# minkowski 424 distance
# (500, 13) (500,)
# manhattan 424 distance
# (500, 13) (500,)
# euclidean 424 distance
# (500, 13) (500,)
# chebyshev 425 distance
# (500, 13) (500,)
# minkowski 425 distance
# (500, 13) (500,)
# manhattan 425 distance
# (500, 13) (500,)
# euclidean 425 distance
# (500, 13) (500,)
# chebyshev 426 distance
# (500, 13) (500,)
# minkowski 426 distance
# (500, 13) (500,)
# manhattan 426 distance
# (500, 13) (500,)
# euclidean 426 distance
# (500, 13) (500,)
# chebyshev 427 distance
# (500, 13) (500,)
# minkowski 427 distance
# (500, 13) (500,)
# manhattan 427 distance
# (500, 13) (500,)
# euclidean 427 distance
# (500, 13) (500,)
# chebyshev 428 distance
# (500, 13) (500,)
# minkowski 428 distance
# (500, 13) (500,)
# manhattan 428 distance
# (500, 13) (500,)
# euclidean 428 distance
# (500, 13) (500,)
# chebyshev 429 distance
# (500, 13) (500,)
# minkowski 429 distance
# (500, 13) (500,)
# manhattan 429 distance
# (500, 13) (500,)
# euclidean 429 distance
# (500, 13) (500,)
# chebyshev 430 distance
# (500, 13) (500,)
# minkowski 430 distance
# (500, 13) (500,)
# manhattan 430 distance
# (500, 13) (500,)
# euclidean 430 distance
# (500, 13) (500,)
# chebyshev 431 distance
# (500, 13) (500,)
# minkowski 431 distance
# (500, 13) (500,)
# manhattan 431 distance
# (500, 13) (500,)
# euclidean 431 distance
# (500, 13) (500,)
# chebyshev 432 distance
# (500, 13) (500,)
# minkowski 432 distance
# (500, 13) (500,)
# manhattan 432 distance
# (500, 13) (500,)
# euclidean 432 distance
# (500, 13) (500,)
# chebyshev 433 distance
# (500, 13) (500,)
# minkowski 433 distance
# (500, 13) (500,)
# manhattan 433 distance
# (500, 13) (500,)
# euclidean 433 distance
# (500, 13) (500,)
# chebyshev 434 distance
# (500, 13) (500,)
# minkowski 434 distance
# (500, 13) (500,)
# manhattan 434 distance
# (500, 13) (500,)
# euclidean 434 distance
# (500, 13) (500,)
# chebyshev 435 distance
# (500, 13) (500,)
# minkowski 435 distance
# (500, 13) (500,)
# manhattan 435 distance
# (500, 13) (500,)
# euclidean 435 distance
# (500, 13) (500,)
# chebyshev 436 distance
# (500, 13) (500,)
# minkowski 436 distance
# (500, 13) (500,)
# manhattan 436 distance
# (500, 13) (500,)
# euclidean 436 distance
# (500, 13) (500,)
# chebyshev 437 distance
# (500, 13) (500,)
# minkowski 437 distance
# (500, 13) (500,)
# manhattan 437 distance
# (500, 13) (500,)
# euclidean 437 distance
# (500, 13) (500,)
# chebyshev 438 distance
# (500, 13) (500,)
# minkowski 438 distance
# (500, 13) (500,)
# manhattan 438 distance
# (500, 13) (500,)
# euclidean 438 distance
# (500, 13) (500,)
# chebyshev 439 distance
# (500, 13) (500,)
# minkowski 439 distance
# (500, 13) (500,)
# manhattan 439 distance
# (500, 13) (500,)
# euclidean 439 distance
# (500, 13) (500,)
# chebyshev 440 distance
# (500, 13) (500,)
# minkowski 440 distance
# (500, 13) (500,)
# manhattan 440 distance
# (500, 13) (500,)
# euclidean 440 distance
# (500, 13) (500,)
# chebyshev 441 distance
# (500, 13) (500,)
# minkowski 441 distance
# (500, 13) (500,)
# manhattan 441 distance
# (500, 13) (500,)
# euclidean 441 distance
# (500, 13) (500,)
# chebyshev 442 distance
# (500, 13) (500,)
# minkowski 442 distance
# (500, 13) (500,)
# manhattan 442 distance
# (500, 13) (500,)
# euclidean 442 distance
# (500, 13) (500,)
# chebyshev 443 distance
# (500, 13) (500,)
# minkowski 443 distance
# (500, 13) (500,)
# manhattan 443 distance
# (500, 13) (500,)
# euclidean 443 distance
# (500, 13) (500,)
# chebyshev 444 distance
# (500, 13) (500,)
# minkowski 444 distance
# (500, 13) (500,)
# manhattan 444 distance
# (500, 13) (500,)
# euclidean 444 distance
# (500, 13) (500,)
# chebyshev 445 distance
# (500, 13) (500,)
# minkowski 445 distance
# (500, 13) (500,)
# manhattan 445 distance
# (500, 13) (500,)
# euclidean 445 distance
# (500, 13) (500,)
# chebyshev 446 distance
# (500, 13) (500,)
# minkowski 446 distance
# (500, 13) (500,)
# manhattan 446 distance
# (500, 13) (500,)
# euclidean 446 distance
# (500, 13) (500,)
# chebyshev 447 distance
# (500, 13) (500,)
# minkowski 447 distance
# (500, 13) (500,)
# manhattan 447 distance
# (500, 13) (500,)
# euclidean 447 distance
# (500, 13) (500,)
# chebyshev 448 distance
# (500, 13) (500,)
# minkowski 448 distance
# (500, 13) (500,)
# manhattan 448 distance
# (500, 13) (500,)
# euclidean 448 distance
# (500, 13) (500,)
# chebyshev 449 distance
# (500, 13) (500,)
# minkowski 449 distance
# (500, 13) (500,)
# manhattan 449 distance
# (500, 13) (500,)
# euclidean 449 distance
# (500, 13) (500,)
# chebyshev 450 distance
# (500, 13) (500,)
# minkowski 450 distance
# (500, 13) (500,)
# manhattan 450 distance
# (500, 13) (500,)
# euclidean 450 distance
# (500, 13) (500,)
# chebyshev 451 distance
# (500, 13) (500,)
# minkowski 451 distance
# (500, 13) (500,)
# manhattan 451 distance
# (500, 13) (500,)
# euclidean 451 distance
# (500, 13) (500,)
# chebyshev 452 distance
# (500, 13) (500,)
# minkowski 452 distance
# (500, 13) (500,)
# manhattan 452 distance
# (500, 13) (500,)
# euclidean 452 distance
# (500, 13) (500,)
# chebyshev 453 distance
# (500, 13) (500,)
# minkowski 453 distance
# (500, 13) (500,)
# manhattan 453 distance
# (500, 13) (500,)
# euclidean 453 distance
# (500, 13) (500,)
# chebyshev 454 distance
# (500, 13) (500,)
# minkowski 454 distance
# (500, 13) (500,)
# manhattan 454 distance
# (500, 13) (500,)
# euclidean 454 distance
# (500, 13) (500,)
# chebyshev 455 distance
# (500, 13) (500,)
# minkowski 455 distance
# (500, 13) (500,)
# manhattan 455 distance
# (500, 13) (500,)
# euclidean 455 distance
# (500, 13) (500,)
# chebyshev 456 distance
# (500, 13) (500,)
# minkowski 456 distance
# (500, 13) (500,)
# manhattan 456 distance
# (500, 13) (500,)
# euclidean 456 distance
# (500, 13) (500,)
# chebyshev 457 distance
# (500, 13) (500,)
# minkowski 457 distance
# (500, 13) (500,)
# manhattan 457 distance
# (500, 13) (500,)
# euclidean 457 distance
# (500, 13) (500,)
# chebyshev 458 distance
# (500, 13) (500,)
# minkowski 458 distance
# (500, 13) (500,)
# manhattan 458 distance
# (500, 13) (500,)
# euclidean 458 distance
# (500, 13) (500,)
# chebyshev 459 distance
# (500, 13) (500,)
# minkowski 459 distance
# (500, 13) (500,)
# manhattan 459 distance
# (500, 13) (500,)
# euclidean 459 distance
# (500, 13) (500,)
# chebyshev 460 distance
# (500, 13) (500,)
# minkowski 460 distance
# (500, 13) (500,)
# manhattan 460 distance
# (500, 13) (500,)
# euclidean 460 distance
# (500, 13) (500,)
# chebyshev 461 distance
# (500, 13) (500,)
# minkowski 461 distance
# (500, 13) (500,)
# manhattan 461 distance
# (500, 13) (500,)
# euclidean 461 distance
# (500, 13) (500,)
# chebyshev 462 distance
# (500, 13) (500,)
# minkowski 462 distance
# (500, 13) (500,)
# manhattan 462 distance
# (500, 13) (500,)
# euclidean 462 distance
# (500, 13) (500,)
# chebyshev 463 distance
# (500, 13) (500,)
# minkowski 463 distance
# (500, 13) (500,)
# manhattan 463 distance
# (500, 13) (500,)
# euclidean 463 distance
# (500, 13) (500,)
# chebyshev 464 distance
# (500, 13) (500,)
# minkowski 464 distance
# (500, 13) (500,)
# manhattan 464 distance
# (500, 13) (500,)
# euclidean 464 distance
# (500, 13) (500,)
# chebyshev 465 distance
# (500, 13) (500,)
# minkowski 465 distance
# (500, 13) (500,)
# manhattan 465 distance
# (500, 13) (500,)
# euclidean 465 distance
# (500, 13) (500,)
# chebyshev 466 distance
# (500, 13) (500,)
# minkowski 466 distance
# (500, 13) (500,)
# manhattan 466 distance
# (500, 13) (500,)
# euclidean 466 distance
# (500, 13) (500,)
# chebyshev 467 distance
# (500, 13) (500,)
# minkowski 467 distance
# (500, 13) (500,)
# manhattan 467 distance
# (500, 13) (500,)
# euclidean 467 distance
# (500, 13) (500,)
# chebyshev 468 distance
# (500, 13) (500,)
# minkowski 468 distance
# (500, 13) (500,)
# manhattan 468 distance
# (500, 13) (500,)
# euclidean 468 distance
# (500, 13) (500,)
# chebyshev 469 distance
# (500, 13) (500,)
# minkowski 469 distance
# (500, 13) (500,)
# manhattan 469 distance
# (500, 13) (500,)
# euclidean 469 distance
# (500, 13) (500,)
# chebyshev 470 distance
# (500, 13) (500,)
# minkowski 470 distance
# (500, 13) (500,)
# manhattan 470 distance
# (500, 13) (500,)
# euclidean 470 distance
# (500, 13) (500,)
# chebyshev 471 distance
# (500, 13) (500,)
# minkowski 471 distance
# (500, 13) (500,)
# manhattan 471 distance
# (500, 13) (500,)
# euclidean 471 distance
# (500, 13) (500,)
# chebyshev 472 distance
# (500, 13) (500,)
# minkowski 472 distance
# (500, 13) (500,)
# manhattan 472 distance
# (500, 13) (500,)
# euclidean 472 distance
# (500, 13) (500,)
# chebyshev 473 distance
# (500, 13) (500,)
# minkowski 473 distance
# (500, 13) (500,)
# manhattan 473 distance
# (500, 13) (500,)
# euclidean 473 distance
# (500, 13) (500,)
# chebyshev 474 distance
# (500, 13) (500,)
# minkowski 474 distance
# (500, 13) (500,)
# manhattan 474 distance
# (500, 13) (500,)
# euclidean 474 distance
# (500, 13) (500,)
# chebyshev 475 distance
# (500, 13) (500,)
# minkowski 475 distance
# (500, 13) (500,)
# manhattan 475 distance
# (500, 13) (500,)
# euclidean 475 distance
# (500, 13) (500,)
# chebyshev 476 distance
# (500, 13) (500,)
# minkowski 476 distance
# (500, 13) (500,)
# manhattan 476 distance
# (500, 13) (500,)
# euclidean 476 distance
# (500, 13) (500,)
# chebyshev 477 distance
# (500, 13) (500,)
# minkowski 477 distance
# (500, 13) (500,)
# manhattan 477 distance
# (500, 13) (500,)
# euclidean 477 distance
# (500, 13) (500,)
# chebyshev 478 distance
# (500, 13) (500,)
# minkowski 478 distance
# (500, 13) (500,)
# manhattan 478 distance
# (500, 13) (500,)
# euclidean 478 distance
# (500, 13) (500,)
# chebyshev 479 distance
# (500, 13) (500,)
# minkowski 479 distance
# (500, 13) (500,)
# manhattan 479 distance
# (500, 13) (500,)
# euclidean 479 distance
# (500, 13) (500,)
# chebyshev 480 distance
# (500, 13) (500,)
# minkowski 480 distance
# (500, 13) (500,)
# manhattan 480 distance
# (500, 13) (500,)
# euclidean 480 distance
# (500, 13) (500,)
# chebyshev 481 distance
# (500, 13) (500,)
# minkowski 481 distance
# (500, 13) (500,)
# manhattan 481 distance
# (500, 13) (500,)
# euclidean 481 distance
# (500, 13) (500,)
# chebyshev 482 distance
# (500, 13) (500,)
# minkowski 482 distance
# (500, 13) (500,)
# manhattan 482 distance
# (500, 13) (500,)
# euclidean 482 distance
# (500, 13) (500,)
# chebyshev 483 distance
# (500, 13) (500,)
# minkowski 483 distance
# (500, 13) (500,)
# manhattan 483 distance
# (500, 13) (500,)
# euclidean 483 distance
# (500, 13) (500,)
# chebyshev 484 distance
# (500, 13) (500,)
# minkowski 484 distance
# (500, 13) (500,)
# manhattan 484 distance
# (500, 13) (500,)
# euclidean 484 distance
# (500, 13) (500,)
# chebyshev 485 distance
# (500, 13) (500,)
# minkowski 485 distance
# (500, 13) (500,)
# manhattan 485 distance
# (500, 13) (500,)
# euclidean 485 distance
# (500, 13) (500,)
# chebyshev 486 distance
# (500, 13) (500,)
# minkowski 486 distance
# (500, 13) (500,)
# manhattan 486 distance
# (500, 13) (500,)
# euclidean 486 distance
# (500, 13) (500,)
# chebyshev 487 distance
# (500, 13) (500,)
# minkowski 487 distance
# (500, 13) (500,)
# manhattan 487 distance
# (500, 13) (500,)
# euclidean 487 distance
# (500, 13) (500,)
# chebyshev 488 distance
# (500, 13) (500,)
# minkowski 488 distance
# (500, 13) (500,)
# manhattan 488 distance
# (500, 13) (500,)
# euclidean 488 distance
# (500, 13) (500,)
# chebyshev 489 distance
# (500, 13) (500,)
# minkowski 489 distance
# (500, 13) (500,)
# manhattan 489 distance
# (500, 13) (500,)
# euclidean 489 distance
# (500, 13) (500,)
# chebyshev 490 distance
# (500, 13) (500,)
# minkowski 490 distance
# (500, 13) (500,)
# manhattan 490 distance
# (500, 13) (500,)
# euclidean 490 distance
# (500, 13) (500,)
# chebyshev 491 distance
# (500, 13) (500,)
# minkowski 491 distance
# (500, 13) (500,)
# manhattan 491 distance
# (500, 13) (500,)
# euclidean 491 distance
# (500, 13) (500,)
# chebyshev 492 distance
# (500, 13) (500,)
# minkowski 492 distance
# (500, 13) (500,)
# manhattan 492 distance
# (500, 13) (500,)
# euclidean 492 distance
# (500, 13) (500,)
# chebyshev 493 distance
# (500, 13) (500,)
# minkowski 493 distance
# (500, 13) (500,)
# manhattan 493 distance
# (500, 13) (500,)
# euclidean 493 distance
# (500, 13) (500,)
# chebyshev 494 distance
# (500, 13) (500,)
# minkowski 494 distance
# (500, 13) (500,)
# manhattan 494 distance
# (500, 13) (500,)
# euclidean 494 distance
# (500, 13) (500,)
# chebyshev 495 distance
# (500, 13) (500,)
# minkowski 495 distance
# (500, 13) (500,)
# manhattan 495 distance
# (500, 13) (500,)
# euclidean 495 distance
# (500, 13) (500,)
# chebyshev 496 distance
# (500, 13) (500,)
# minkowski 496 distance
# (500, 13) (500,)
# manhattan 496 distance
# (500, 13) (500,)
# euclidean 496 distance
# (500, 13) (500,)
# chebyshev 497 distance
# (500, 13) (500,)
# minkowski 497 distance
# (500, 13) (500,)
# manhattan 497 distance
# (500, 13) (500,)
# euclidean 497 distance
# (500, 13) (500,)
# chebyshev 498 distance
# (500, 13) (500,)
# minkowski 498 distance
# (500, 13) (500,)
# manhattan 498 distance
# (500, 13) (500,)
# euclidean 498 distance
# (500, 13) (500,)
# chebyshev 499 distance
# (500, 13) (500,)
# minkowski 499 distance
# (500, 13) (500,)
# manhattan 499 distance
# (500, 13) (500,)
# euclidean 499 distance
# (500, 13) (500,)

# %%
best_parameters
# Out:
# {'prediction': array([22.58316633]),
#  'mse': 0.3400829715543327,
#  'n_neighbors': 499,
#  'metric': 'minkowski',
#  'weights': 'uniform'}
