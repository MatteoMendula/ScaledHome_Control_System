# %%
import os
import numpy as np
import datetime

# %%
import pandas as pd
def read_data(data_path):
    data_frame = pd.read_csv(data_path)
    #data_frame = data_frame.set_index(pd.DatetimeIndex(data_frame['TIME']))
    #data_frame = data_frame.drop(columns=['icon', 'summary'])
    return data_frame

# %%
DATASET_PATH = "../middleware/data"
# DATASET_PATH = "D:/Thesis draft/code/UCF_ScaledHomeMqtt/middleware/data"
# data_file_name = "data.csv"

# data_file_name = "2_1_2020.csv"
# data_file_name = "2_2_2020.csv"
# data_file_name = "2_3_2020.csv"
# data_file_name = "decrease_outside.csv"
data_file_name = "increase_outside.csv"

# data_file_name = "data-only-increase.csv"
columns_to_drop = ["OUT_H[%]","T6[*C]","H6[%]","T12[*C]","H12[%]","T18[*C]",
                  "H18[%]","T19[*C]","H19[%]","T24[*C]","H24[%]","T25[*C]","H25[%]",
                  "T26[*C]","H26[%]","FAN_STATE","AC_STATE","HEATER_STATE"]

FMT = '%Y-%m-%d %H:%M:%S.%f'

data_path = os.path.join(DATASET_PATH, data_file_name)
# print(data_path.replace('/','\\'))
data = read_data(data_path)
data.head()
# Out:
#                          TIME  OUT_T[*C]  OUT_H[%]  T6[*C]  H6[%]  T12[*C]  \
# 0  2020-02-03 12:01:34.146468       22.0      47.0    26.0   46.0     24.0
# 1  2020-02-03 12:01:45.546825       22.0      47.0    26.0   46.0     24.0
# 2  2020-02-03 12:01:51.841962       22.0      47.0    26.0   46.0     24.0
# 3  2020-02-03 12:02:03.200257       22.0      47.0    26.0   46.0     24.0
# 4  2020-02-03 12:02:12.060122       23.0      46.0    26.0   46.0     25.0
#
#    H12[%]  T18[*C]  H18[%]  T19[*C]  ...  T24[*C]  H24[%]  T25[*C]  H25[%]  \
# 0    40.0     24.0    48.0     27.0  ...     25.0    39.0     24.0    43.0
# 1    43.0     24.0    48.0     27.0  ...     25.0    39.0     24.0    43.0
# 2    43.0     24.0    48.0     27.0  ...     25.0    39.0     24.0    43.0
# 3    40.0     24.0    48.0     27.0  ...     25.0    39.0     24.0    43.0
# 4    43.0     24.0    48.0     27.0  ...     25.0    39.0     24.0    43.0
#
#    T26[*C]  H26[%]  LAMP_STATE  FAN_STATE  AC_STATE  HEATER_STATE
# 0     24.0    46.0           1          0         0             0
# 1     24.0    46.0           1          0         0             0
# 2     24.0    46.0           1          0         0             0
# 3     24.0    46.0           1          0         0             0
# 4     24.0    46.0           1          0         0             0
#
# [5 rows x 21 columns]

# %%
data1 = data.copy()
# for i, j in data1.iterrows(): 
#     j[0] = datetime.datetime.strptime(j[0], '%Y-%m-%d %H:%M:%S.%f').time()
#     print(j[0])

def cleanData(data,cols_to_drop):
    data_cleaned = data.drop(columns=cols_to_drop)
    return data_cleaned
    
def timeDiffence(data):
    time_list = list()
    temp_list = list()
    
    t0 = (data["TIME"][0])
    for i, j in data.iterrows(): 
        el = (datetime.datetime.strptime(j[0], FMT) - datetime.datetime.strptime(t0, FMT)).seconds
        time_list.append(el)
        temp_list.append(j[1])
    return np.array(time_list), np.array(temp_list)
    
data1 = cleanData(data1,columns_to_drop)
time, temp = timeDiffence(data1)
# for el in time:
#     print (el)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()

# %matplotlib inline

ax.plot(time, temp)

ax.set(xlabel='time (s)', ylabel='temp (°C)',
       title='Outside temperature over time')
ax.grid()

fig.savefig("plain_data.png")
plt.show()

# %%
p1 = np.polyfit(time,temp,1)
p2 = np.polyfit(time,temp,2)
p3 = np.polyfit(time,temp,3)

# %%
fig, ax = plt.subplots()

# %matplotlib inline

ax.plot(time, temp, 'o')

ax.plot(time, np.polyval(p1,time),'r-')
ax.plot(time, np.polyval(p2,time),'b-')
ax.plot(time, np.polyval(p3,time),'g-')

ax.set(xlabel='time (s)', ylabel='temp (°C)',
       title='Outside temperature over time')
ax.grid()

fig.savefig("test.png")
plt.show()

# %%
np.argmax(temp)
temp[25]

np.argmin(temp)
temp[13]

time_diff_increase = time[13] - time[25]
time_diff_increase

time_diff_decrease = time[-34] - time[-11]
time_diff_decrease
# Out:
# -195

# %%
fig, ax = plt.subplots()

# %matplotlib inline

ax.plot(time, temp, 'o')
xp = np.linspace(-100,1300,10000)
ax.plot(xp, np.polyval(p1,xp),'r-')
ax.plot(xp, np.polyval(p2,xp),'b-')
ax.plot(xp, np.polyval(p3,xp),'g-')

ax.set(xlabel='time (s)', ylabel='temp (°C)',
       title='Outside temperature over time')
ax.grid()

fig.savefig("test.png")
plt.show()
